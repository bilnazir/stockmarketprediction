# %% [markdown]
# <a href="https://colab.research.google.com/github/bilnazir/stockmarketprediction/blob/main/fyp_transformer_apple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas-ta
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas-ta) (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=57d6c2b443bbfb343bc4afde56f2d8f277c1070eeb99bc5bec9c836b07ff7b01
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
import yfinance as yf

# %%
# Load historical stock data (date, closing price) into a pandas DataFrame
df = yf.download(tickers=['AAPL'], start='2012-01-01', end='2022-06-20')
data = df.dropna()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2633 entries, 2012-01-03 to 2022-06-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2633 non-null   float64
#  1   High       2633 non-null   float64
#  2   Low        2633 non-null   float64
#  3   Close      2633 non-null   float64
#  4   Adj Close  2633 non-null   float64
#  5   Volume     2633 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 144.0 KB

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   14.621429   14.732143   14.607143   14.686786   12.402630
# 2012-01-04   14.642857   14.810000   14.617143   14.765714   12.469281
# 2012-01-05   14.819643   14.948214   14.738214   14.929643   12.607713
# 2012-01-06   14.991786   15.098214   14.972143   15.085714   12.739513
# 2012-01-09   15.196429   15.276786   15.048214   15.061786   12.719306
# ...                ...         ...         ...         ...         ...
# 2022-06-13  132.869995  135.199997  131.440002  131.880005  130.253876
# 2022-06-14  133.130005  133.889999  131.479996  132.759995  131.123032
# 2022-06-15  134.289993  137.339996  132.160004  135.429993  133.760086
# 2022-06-16  132.080002  132.389999  129.039993  130.059998  128.456299
# 2022-06-17  130.070007  133.080002  129.809998  131.559998  129.937790
#
#                Volume
# Date
# 2012-01-03  302220800
# 2012-01-04  260022000
# 2012-01-05  271269600
# 2012-01-06  318292800
# 2012-01-09  394024400
# ...               ...
# 2022-06-13  122207100
# 2022-06-14   84784300
# 2022-06-15   91533000
# 2022-06-16  108123900
# 2022-06-17  134520300
#
# [2633 rows x 6 columns]

# %%
data.shape
# Out:
# (2633, 6)

# %%
# Adding indicators
import pandas_ta as ta
data['RSI'] = ta.rsi(data.Close, length=15)
data['EMAF'] = ta.ema(data.Close, length=20)
data['EMAM'] = ta.ema(data.Close, length=100)
data['EMAS'] = ta.ema(data.Close, length=150)

data['Target'] = data['Adj Close'] - data.Open
data['Target'] = data['Target'].shift(-1)

data['TargetClass'] = [1 if data.Target[i] > 0 else 0 for i in range(len(data))]

data['TargetNextClose'] = data['Adj Close'].shift(-1)

data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Volume', 'Close','Date'], axis=1, inplace=True)
# Out:
# <ipython-input-8-8a8148f44cbd>:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data['TargetClass'] = [1 if data.Target[i] > 0 else 0 for i in range(len(data))]

# %%
data_set = data.iloc[:, 0:11]
pd.set_option('display.max_columns', None)

data_set.head(20)
# Out:
#          Open       High        Low  Adj Close        RSI       EMAF  \
# 0   22.046070  22.316786  21.973572  18.776005  62.709034  21.487612
# 1   22.241785  22.321428  22.072857  18.726538  61.648029  21.553111
# 2   22.121071  22.281429  22.039286  18.694874  60.940716  21.608801
# 3   22.066071  22.204643  22.064285  18.801491  61.334533  21.662147
# 4   22.096786  22.205713  22.096430  18.830872  61.794709  21.713711
# 5   22.263929  22.500000  22.258928  19.082275  65.553213  21.788596
# 6   22.566786  22.807501  22.507500  19.133459  66.276954  21.862097
# 7   22.546429  22.642857  22.419643  19.107414  65.526319  21.925672
# 8   22.543215  22.741428  22.517857  19.274303  68.013223  22.001935
# 9   22.857143  23.149643  22.814644  19.630812  72.545979  22.110968
# 10  23.214643  23.755358  23.210714  20.146944  77.493214  22.267577
# 11  23.957857  24.102858  23.226070  19.871614  70.257098  22.378352
# 12  23.372143  23.892857  23.146786  20.259623  73.932379  22.522148
# 13  23.789642  23.924999  23.612499  20.070620  69.453218  22.631025
# 14  23.553928  23.910000  23.412500  20.088484  69.639548  22.731540
# 15  24.285357  24.316786  24.055000  20.465893  73.321878  22.864863
# 16  24.106428  24.146429  23.952499  20.439236  72.655046  22.982495
# 17  24.116072  24.202499  24.021429  20.398952  71.600593  23.084400
# 18  23.951429  23.983929  23.673214  20.108170  64.375258  23.143947
# 19  23.830357  23.878571  23.473213  20.149673  64.916587  23.202483
#
#          EMAM       EMAS    Target  TargetClass  TargetNextClose
# 0   20.399588  19.740979 -3.515247            0        18.726538
# 1   20.434751  19.773222 -3.426197            0        18.694874
# 2   20.468476  19.804542 -3.264580            0        18.801491
# 3   20.502149  19.835858 -3.265915            0        18.830872
# 4   20.535840  19.867219 -3.181654            0        19.082275
# 5   20.574734  19.902090 -3.433327            0        19.133459
# 6   20.614054  19.937299 -3.439014            0        19.107414
# 7   20.651986  19.971634 -3.268911            0        19.274303
# 8   20.693064  20.008122 -3.226332            0        19.630812
# 9   20.741653  20.049693 -3.067699            0        20.146944
# 10  20.801330  20.098775 -4.086243            0        19.871614
# 11  20.853397  20.142907 -3.112520            0        20.259623
# 12  20.913492  20.192513 -3.719023            0        20.070620
# 13  20.967985  20.238511 -3.465445            0        20.088484
# 14  21.021815  20.284179 -3.819464            0        20.465893
# 15  21.083392  20.335136 -3.667192            0        20.439236
# 16  21.143127  20.385002 -3.717119            0        20.398952
# 17  21.200738  20.433578 -3.843260            0        20.108170
# 18  21.250419  20.476970 -3.680683            0        20.149673
# 19  21.300086  20.520434 -3.332760            0        20.444384

# %%
import matplotlib.pyplot as plt
data_set_AC=data_set['Adj Close']
plt.ylabel('Up-Down Movemetn')
plt.xlabel('Date')
plt.plot(data_set_AC)

# %%
# Normalize the data
sc = MinMaxScaler(feature_range=(0, 1))
data_set_scaled = sc.fit_transform(data)

# %%
# Prepare the data for training
X, y = [], []
backcandles = 20
for i in range(backcandles, data_set_scaled.shape[0]):
    X.append(data_set_scaled[i - backcandles:i, :-1])
    y.append(data_set_scaled[i, -1])

X, y = np.array(X), np.array(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Build the Transformer model
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-head self-attention mechanism
    attn_output = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    attn_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)

    # Feed-forward neural network
    ffn_output = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(attn_output)
    ffn_output = tf.keras.layers.Dropout(dropout)(ffn_output)
    ffn_output = tf.keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(ffn_output)
    return tf.keras.layers.LayerNormalization(epsilon=1e-6)(attn_output + ffn_output)

# %%
# Build the Transformer model
def build_transformer_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
):
    inputs = Input(shape=input_shape)

    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = tf.keras.layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = Dense(dim, activation="relu")(x)
        x = Dropout(dropout)(x)
    outputs = Dense(1)(x)

    return Model(inputs, outputs)

# %%
input_shape = X_train.shape[1:]
head_size = 128
num_heads = 4
ff_dim = 32
num_transformer_blocks = 8
mlp_units = [64, 32]

# %%
# Create and compile the Transformer model
model = build_transformer_model(
    input_shape,
    head_size=head_size,
    num_heads=num_heads,
    ff_dim=ff_dim,
    num_transformer_blocks=num_transformer_blocks,
    mlp_units=mlp_units,
    dropout=0.25,
)

model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

# %%
# Training the model
history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=128,
    validation_data=(X_test, y_test),
    verbose=1,
)
# Out:
# Epoch 1/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 60s 784ms/step - loss: 0.0948 - mean_absolute_error: 0.2188 - val_loss: 0.0031 - val_mean_absolute_error: 0.0435
# Epoch 2/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0241 - mean_absolute_error: 0.1106 - val_loss: 0.0042 - val_mean_absolute_error: 0.0517
# Epoch 3/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0196 - mean_absolute_error: 0.0952 - val_loss: 0.0041 - val_mean_absolute_error: 0.0512
# Epoch 4/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0169 - mean_absolute_error: 0.0865 - val_loss: 0.0060 - val_mean_absolute_error: 0.0627
# Epoch 5/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0136 - mean_absolute_error: 0.0832 - val_loss: 0.0036 - val_mean_absolute_error: 0.0491
# Epoch 6/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0118 - mean_absolute_error: 0.0686 - val_loss: 0.0062 - val_mean_absolute_error: 0.0624
# Epoch 7/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0131 - mean_absolute_error: 0.0740 - val_loss: 0.0049 - val_mean_absolute_error: 0.0477
# Epoch 8/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0098 - mean_absolute_error: 0.0647 - val_loss: 0.0049 - val_mean_absolute_error: 0.0476
# Epoch 9/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0084 - mean_absolute_error: 0.0580 - val_loss: 0.0027 - val_mean_absolute_error: 0.0417
# Epoch 10/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0100 - mean_absolute_error: 0.0622 - val_loss: 0.0039 - val_mean_absolute_error: 0.0521
# Epoch 11/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0074 - mean_absolute_error: 0.0549 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
# Epoch 12/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068 - mean_absolute_error: 0.0528 - val_loss: 0.0016 - val_mean_absolute_error: 0.0326
# Epoch 13/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0076 - mean_absolute_error: 0.0530 - val_loss: 0.0029 - val_mean_absolute_error: 0.0404
# Epoch 14/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0067 - mean_absolute_error: 0.0515 - val_loss: 0.0022 - val_mean_absolute_error: 0.0339
# Epoch 15/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0067 - mean_absolute_error: 0.0524 - val_loss: 0.0040 - val_mean_absolute_error: 0.0403
# Epoch 16/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0063 - mean_absolute_error: 0.0502 - val_loss: 0.0032 - val_mean_absolute_error: 0.0416
# Epoch 17/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0058 - mean_absolute_error: 0.0509 - val_loss: 0.0019 - val_mean_absolute_error: 0.0312
# Epoch 18/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0056 - mean_absolute_error: 0.0481 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 19/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0045 - mean_absolute_error: 0.0430 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 20/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0060 - mean_absolute_error: 0.0533 - val_loss: 8.3028e-04 - val_mean_absolute_error: 0.0202
# Epoch 21/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0055 - mean_absolute_error: 0.0446 - val_loss: 0.0013 - val_mean_absolute_error: 0.0238
# Epoch 22/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0045 - mean_absolute_error: 0.0437 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 23/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0056 - mean_absolute_error: 0.0491 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
# Epoch 24/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0049 - mean_absolute_error: 0.0431 - val_loss: 0.0025 - val_mean_absolute_error: 0.0356
# Epoch 25/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0051 - mean_absolute_error: 0.0465 - val_loss: 0.0036 - val_mean_absolute_error: 0.0442
# Epoch 26/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0047 - mean_absolute_error: 0.0450 - val_loss: 0.0018 - val_mean_absolute_error: 0.0333
# Epoch 27/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0051 - mean_absolute_error: 0.0485 - val_loss: 0.0020 - val_mean_absolute_error: 0.0322
# Epoch 28/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0046 - mean_absolute_error: 0.0439 - val_loss: 0.0029 - val_mean_absolute_error: 0.0381
# Epoch 29/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0051 - mean_absolute_error: 0.0489 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 30/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0043 - mean_absolute_error: 0.0437 - val_loss: 9.7977e-04 - val_mean_absolute_error: 0.0212
# Epoch 31/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - mean_absolute_error: 0.0401 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 32/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0039 - mean_absolute_error: 0.0434 - val_loss: 0.0021 - val_mean_absolute_error: 0.0290
# Epoch 33/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0048 - mean_absolute_error: 0.0453 - val_loss: 9.5876e-04 - val_mean_absolute_error: 0.0242
# Epoch 34/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0036 - mean_absolute_error: 0.0393 - val_loss: 0.0016 - val_mean_absolute_error: 0.0273
# Epoch 35/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046 - mean_absolute_error: 0.0426 - val_loss: 9.8105e-04 - val_mean_absolute_error: 0.0241
# Epoch 36/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0040 - mean_absolute_error: 0.0408 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 37/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0042 - mean_absolute_error: 0.0419 - val_loss: 8.9292e-04 - val_mean_absolute_error: 0.0184
# Epoch 38/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - mean_absolute_error: 0.0397 - val_loss: 7.7275e-04 - val_mean_absolute_error: 0.0207
# Epoch 39/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0039 - mean_absolute_error: 0.0404 - val_loss: 0.0012 - val_mean_absolute_error: 0.0284
# Epoch 40/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0040 - mean_absolute_error: 0.0426 - val_loss: 6.8316e-04 - val_mean_absolute_error: 0.0165
# Epoch 41/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0043 - mean_absolute_error: 0.0419 - val_loss: 8.7846e-04 - val_mean_absolute_error: 0.0234
# Epoch 42/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - mean_absolute_error: 0.0403 - val_loss: 0.0014 - val_mean_absolute_error: 0.0302
# Epoch 43/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0049 - mean_absolute_error: 0.0466 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 44/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0039 - mean_absolute_error: 0.0426 - val_loss: 9.2326e-04 - val_mean_absolute_error: 0.0206
# Epoch 45/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036 - mean_absolute_error: 0.0399 - val_loss: 0.0015 - val_mean_absolute_error: 0.0303
# Epoch 46/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0035 - mean_absolute_error: 0.0392 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 47/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0034 - mean_absolute_error: 0.0390 - val_loss: 9.9296e-04 - val_mean_absolute_error: 0.0256
# Epoch 48/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0037 - mean_absolute_error: 0.0408 - val_loss: 0.0033 - val_mean_absolute_error: 0.0467
# Epoch 49/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0041 - mean_absolute_error: 0.0429 - val_loss: 9.2636e-04 - val_mean_absolute_error: 0.0254
# Epoch 50/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034 - mean_absolute_error: 0.0381 - val_loss: 7.2176e-04 - val_mean_absolute_error: 0.0196
# Epoch 51/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0038 - mean_absolute_error: 0.0401 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 52/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034 - mean_absolute_error: 0.0376 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 53/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - mean_absolute_error: 0.0392 - val_loss: 9.8962e-04 - val_mean_absolute_error: 0.0234
# Epoch 54/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0038 - mean_absolute_error: 0.0396 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 55/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mean_absolute_error: 0.0374 - val_loss: 9.0800e-04 - val_mean_absolute_error: 0.0242
# Epoch 56/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032 - mean_absolute_error: 0.0384 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277
# Epoch 57/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mean_absolute_error: 0.0365 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# Epoch 58/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034 - mean_absolute_error: 0.0393 - val_loss: 8.0531e-04 - val_mean_absolute_error: 0.0179
# Epoch 59/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0355 - val_loss: 0.0012 - val_mean_absolute_error: 0.0285
# Epoch 60/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034 - mean_absolute_error: 0.0387 - val_loss: 5.5115e-04 - val_mean_absolute_error: 0.0160
# Epoch 61/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0037 - mean_absolute_error: 0.0383 - val_loss: 0.0020 - val_mean_absolute_error: 0.0370
# Epoch 62/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - mean_absolute_error: 0.0407 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 63/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0366 - val_loss: 6.8201e-04 - val_mean_absolute_error: 0.0186
# Epoch 64/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034 - mean_absolute_error: 0.0385 - val_loss: 7.5720e-04 - val_mean_absolute_error: 0.0175
# Epoch 65/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0365 - val_loss: 6.1423e-04 - val_mean_absolute_error: 0.0183
# Epoch 66/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0032 - mean_absolute_error: 0.0381 - val_loss: 5.3084e-04 - val_mean_absolute_error: 0.0169
# Epoch 67/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - mean_absolute_error: 0.0405 - val_loss: 0.0012 - val_mean_absolute_error: 0.0252
# Epoch 68/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0038 - mean_absolute_error: 0.0402 - val_loss: 6.7551e-04 - val_mean_absolute_error: 0.0175
# Epoch 69/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0030 - mean_absolute_error: 0.0378 - val_loss: 7.1832e-04 - val_mean_absolute_error: 0.0184
# Epoch 70/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0030 - mean_absolute_error: 0.0372 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 71/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0036 - mean_absolute_error: 0.0393 - val_loss: 8.3505e-04 - val_mean_absolute_error: 0.0210
# Epoch 72/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0032 - mean_absolute_error: 0.0389 - val_loss: 5.0330e-04 - val_mean_absolute_error: 0.0173
# Epoch 73/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0376 - val_loss: 0.0011 - val_mean_absolute_error: 0.0234
# Epoch 74/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0032 - mean_absolute_error: 0.0387 - val_loss: 9.0982e-04 - val_mean_absolute_error: 0.0199
# Epoch 75/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0374 - val_loss: 4.8744e-04 - val_mean_absolute_error: 0.0159
# Epoch 76/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032 - mean_absolute_error: 0.0387 - val_loss: 5.8926e-04 - val_mean_absolute_error: 0.0183
# Epoch 77/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034 - mean_absolute_error: 0.0394 - val_loss: 0.0011 - val_mean_absolute_error: 0.0234
# Epoch 78/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0367 - val_loss: 7.9243e-04 - val_mean_absolute_error: 0.0226
# Epoch 79/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0034 - mean_absolute_error: 0.0407 - val_loss: 4.5158e-04 - val_mean_absolute_error: 0.0159
# Epoch 80/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - mean_absolute_error: 0.0379 - val_loss: 8.4647e-04 - val_mean_absolute_error: 0.0238
# Epoch 81/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - mean_absolute_error: 0.0389 - val_loss: 6.5904e-04 - val_mean_absolute_error: 0.0189
# Epoch 82/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - mean_absolute_error: 0.0403 - val_loss: 7.4485e-04 - val_mean_absolute_error: 0.0181
# Epoch 83/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0359 - val_loss: 8.6172e-04 - val_mean_absolute_error: 0.0216
# Epoch 84/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0361 - val_loss: 6.3948e-04 - val_mean_absolute_error: 0.0214
# Epoch 85/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0355 - val_loss: 0.0011 - val_mean_absolute_error: 0.0229
# Epoch 86/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0035 - mean_absolute_error: 0.0400 - val_loss: 0.0010 - val_mean_absolute_error: 0.0222
# Epoch 87/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0030 - mean_absolute_error: 0.0366 - val_loss: 6.4317e-04 - val_mean_absolute_error: 0.0161
# Epoch 88/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0339 - val_loss: 4.4130e-04 - val_mean_absolute_error: 0.0152
# Epoch 89/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0349 - val_loss: 0.0014 - val_mean_absolute_error: 0.0277
# Epoch 90/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - mean_absolute_error: 0.0393 - val_loss: 4.9134e-04 - val_mean_absolute_error: 0.0156
# Epoch 91/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0359 - val_loss: 5.0885e-04 - val_mean_absolute_error: 0.0140
# Epoch 92/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0356 - val_loss: 5.6264e-04 - val_mean_absolute_error: 0.0148
# Epoch 93/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0024 - mean_absolute_error: 0.0352 - val_loss: 5.0085e-04 - val_mean_absolute_error: 0.0167
# Epoch 94/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0340 - val_loss: 4.4085e-04 - val_mean_absolute_error: 0.0149
# Epoch 95/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mean_absolute_error: 0.0363 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
# Epoch 96/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0032 - mean_absolute_error: 0.0400 - val_loss: 0.0023 - val_mean_absolute_error: 0.0372
# Epoch 97/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mean_absolute_error: 0.0375 - val_loss: 4.7666e-04 - val_mean_absolute_error: 0.0160
# Epoch 98/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0025 - mean_absolute_error: 0.0356 - val_loss: 4.8194e-04 - val_mean_absolute_error: 0.0153
# Epoch 99/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0345 - val_loss: 6.7424e-04 - val_mean_absolute_error: 0.0200
# Epoch 100/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mean_absolute_error: 0.0358 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 101/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028 - mean_absolute_error: 0.0368 - val_loss: 0.0011 - val_mean_absolute_error: 0.0230
# Epoch 102/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026 - mean_absolute_error: 0.0361 - val_loss: 4.1935e-04 - val_mean_absolute_error: 0.0149
# Epoch 103/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028 - mean_absolute_error: 0.0349 - val_loss: 6.3035e-04 - val_mean_absolute_error: 0.0166
# Epoch 104/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0360 - val_loss: 0.0013 - val_mean_absolute_error: 0.0223
# Epoch 105/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0028 - mean_absolute_error: 0.0363 - val_loss: 7.4301e-04 - val_mean_absolute_error: 0.0182
# Epoch 106/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0342 - val_loss: 5.6150e-04 - val_mean_absolute_error: 0.0151
# Epoch 107/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0024 - mean_absolute_error: 0.0331 - val_loss: 9.1745e-04 - val_mean_absolute_error: 0.0256
# Epoch 108/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0360 - val_loss: 7.7098e-04 - val_mean_absolute_error: 0.0203
# Epoch 109/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0024 - mean_absolute_error: 0.0335 - val_loss: 7.9443e-04 - val_mean_absolute_error: 0.0231
# Epoch 110/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0342 - val_loss: 9.2089e-04 - val_mean_absolute_error: 0.0213
# Epoch 111/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0363 - val_loss: 6.0372e-04 - val_mean_absolute_error: 0.0166
# Epoch 112/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0012 - val_mean_absolute_error: 0.0236
# Epoch 113/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032 - mean_absolute_error: 0.0394 - val_loss: 4.3770e-04 - val_mean_absolute_error: 0.0157
# Epoch 114/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0362 - val_loss: 9.5703e-04 - val_mean_absolute_error: 0.0253
# Epoch 115/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0368 - val_loss: 8.2798e-04 - val_mean_absolute_error: 0.0246
# Epoch 116/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0029 - mean_absolute_error: 0.0361 - val_loss: 7.0131e-04 - val_mean_absolute_error: 0.0191
# Epoch 117/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0027 - mean_absolute_error: 0.0349 - val_loss: 9.5545e-04 - val_mean_absolute_error: 0.0231
# Epoch 118/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - mean_absolute_error: 0.0381 - val_loss: 0.0023 - val_mean_absolute_error: 0.0372
# Epoch 119/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0029 - mean_absolute_error: 0.0363 - val_loss: 0.0016 - val_mean_absolute_error: 0.0283
# Epoch 120/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - mean_absolute_error: 0.0363 - val_loss: 6.5413e-04 - val_mean_absolute_error: 0.0201
# Epoch 121/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mean_absolute_error: 0.0383 - val_loss: 4.3007e-04 - val_mean_absolute_error: 0.0143
# Epoch 122/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026 - mean_absolute_error: 0.0349 - val_loss: 4.8304e-04 - val_mean_absolute_error: 0.0160
# Epoch 123/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0339 - val_loss: 7.3421e-04 - val_mean_absolute_error: 0.0218
# Epoch 124/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0028 - mean_absolute_error: 0.0349 - val_loss: 8.6625e-04 - val_mean_absolute_error: 0.0239
# Epoch 125/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0340 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 126/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0350 - val_loss: 8.0130e-04 - val_mean_absolute_error: 0.0230
# Epoch 127/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.0010 - val_mean_absolute_error: 0.0275
# Epoch 128/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028 - mean_absolute_error: 0.0358 - val_loss: 8.7916e-04 - val_mean_absolute_error: 0.0231

# %%
# Convert training history to datafram for viewing and graphing.
hist = pd.DataFrame(history.history)
hist.head()
# Out:
#        loss  mean_absolute_error  val_loss  val_mean_absolute_error
# 0  0.057198             0.167532  0.003091                 0.043504
# 1  0.022819             0.105871  0.004171                 0.051688
# 2  0.018983             0.092240  0.004142                 0.051175
# 3  0.016152             0.087329  0.006016                 0.062655
# 4  0.013837             0.081195  0.003569                 0.049100

# %%
# Training errors with respect to ecochs.
# loss: values of the cost function for training data.
# val_loss: values of the cost function for cross-validation data.
hist.plot()
# Out:
# <Axes: >

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 20, 10)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 20, 10)         │         22,026 │ input_layer[0][0],     │
# │ (MultiHeadAttention)      │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 20, 10)         │              0 │ input_layer[0][0],     │
# │                           │                        │                │ multi_head_attention[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 20, 10)         │             20 │ add[0][0]              │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 20, 32)         │            352 │ layer_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization[0… │
# │                           │                        │                │ conv1d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_1     │ (None, 20, 10)         │             20 │ add_1[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_1    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_2     │ (None, 20, 10)         │             20 │ add_2[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_3 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_2… │
# │                           │                        │                │ conv1d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_3     │ (None, 20, 10)         │             20 │ add_3[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_2    │ (None, 20, 10)         │         22,026 │ layer_normalization_3… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_3… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_4     │ (None, 20, 10)         │             20 │ add_4[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_4 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_5 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_4… │
# │                           │                        │                │ conv1d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_5     │ (None, 20, 10)         │             20 │ add_5[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_3    │ (None, 20, 10)         │         22,026 │ layer_normalization_5… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_5… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_6     │ (None, 20, 10)         │             20 │ add_6[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_6 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_7 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_6… │
# │                           │                        │                │ conv1d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_7     │ (None, 20, 10)         │             20 │ add_7[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_4    │ (None, 20, 10)         │         22,026 │ layer_normalization_7… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_7… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_8     │ (None, 20, 10)         │             20 │ add_8[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_8 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_9 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_8… │
# │                           │                        │                │ conv1d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_9     │ (None, 20, 10)         │             20 │ add_9[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_5    │ (None, 20, 10)         │         22,026 │ layer_normalization_9… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_9… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_10    │ (None, 20, 10)         │             20 │ add_10[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_10 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_11 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_11    │ (None, 20, 10)         │             20 │ add_11[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_6    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_12    │ (None, 20, 10)         │             20 │ add_12[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_12 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_13 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_13 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_13    │ (None, 20, 10)         │             20 │ add_13[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_7    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 20, 10)         │             20 │ add_14[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_14 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_15 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_15 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 20, 10)         │             20 │ add_15[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 10)             │              0 │ layer_normalization_1… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │            704 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_16 (Dropout)      │ (None, 64)             │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 32)             │          2,080 │ dropout_16[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 32)             │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │             33 │ dropout_17[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 554,405 (2.11 MB)
#  Trainable params: 184,801 (721.88 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 369,604 (1.41 MB)

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) score
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2) score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.0231
# Mean Squared Error (MSE): 0.0009
# Root Mean Squared Error (RMSE): 0.0297
# R-squared (R2) score: 0.9869

# %%
# Plot the actual and predicted adjacent closing prices
# Assuming y_test and y_pred are numpy arrays
y_test = y_test.squeeze()
y_pred = y_pred.squeeze()

plt.figure(figsize=(10, 6))  # Increase figure size for better visibility

# Plot actual values as blue circles
plt.plot(y_test, label='Actual Adjacent Close', color='orange', marker='o', linestyle='-', markersize=5)

# Plot predicted values as red triangles
plt.plot(y_pred, label='Predicted Adjacent Close', color='green', marker='^', linestyle='--', markersize=5)

plt.xlabel('Time')
plt.ylabel('Adjacent Closing Price')
plt.title('Actual vs. Predicted Adjacent Closing Price')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
# Scatter plot of actual vs. predicted adjacent closing prices
plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

# Plot actual values as orange circles with larger markers
plt.scatter(y_test, y_test, color='orange', label='Actual Adjacent Closing Price', alpha=0.7, s=60)

# Plot predicted values as black crosses with smaller markers
plt.scatter(y_test, y_pred, color='green', label='Predicted Adjacent Closing Price', alpha=0.7, s=40, marker='x')

# Plot the diagonal line for perfect predictions
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--', label='Perfect Prediction')

plt.xlabel('Actual Adjacent Closing Price')
plt.ylabel('Predicted Adjacent Closing Price')
plt.title('Scatter Plot of Actual vs. Predicted Adjacent Closing Price')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
# Histogram of prediction errors
errors = y_test - y_pred

plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

plt.hist(errors, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Histogram of Prediction Errors')

# Add grid lines for better readability
plt.grid(True)

plt.show()
