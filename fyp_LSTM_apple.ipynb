# %% [markdown]
# <a href="https://colab.research.google.com/github/bilnazir/stockmarketprediction/blob/main/fyp_LSTM_apple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas-ta
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas-ta) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218907 sha256=c707ff310f8eca9ea8102a0a9d9b6fcbc1febc101c89832192f5f973f50961f3
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
import pandas_ta as ta

data = yf.download(tickers = 'AAPL', start = '2012-03-11',end = '2022-07-10')
data.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2012-03-12  19.606428  19.714287  19.535713  19.714287  16.667490   407282400
# 2012-03-13  19.912144  20.292143  19.848213  20.289286  17.153633   690855200
# 2012-03-14  20.644644  21.240000  20.549999  21.056429  17.802216  1418844000
# 2012-03-15  21.414642  21.428928  20.662500  20.912857  17.680834  1159718000
# 2012-03-16  20.882856  21.042856  20.642857  20.913214  17.681137   825487600
# 2012-03-19  21.370358  21.491785  21.037500  21.467857  18.150057   901236000
# 2012-03-20  21.411072  21.674999  21.124287  21.641430  18.296806   816662000
# 2012-03-21  21.526428  21.773214  21.478930  21.517857  18.192331   644042000
# 2012-03-22  21.349285  21.589287  21.268929  21.405001  18.096914   623870800
# 2012-03-23  21.446072  21.492857  21.228571  21.287500  17.997580   430488800

# %%
# Adding indicators
data['RSI']=ta.rsi(data.Close, length=15)
data['EMAF']=ta.ema(data.Close, length=20)
data['EMAM']=ta.ema(data.Close, length=100)
data['EMAS']=ta.ema(data.Close, length=150)

data['Target'] = data['Adj Close']-data.Open
data['Target'] = data['Target'].shift(-1)

data['TargetClass'] = [1 if data.Target[i]>0 else 0 for i in range(len(data))]

data['TargetNextClose'] = data['Adj Close'].shift(-1)

data.dropna(inplace=True)
data.reset_index(inplace = True)
data.drop(['Volume', 'Close', 'Date'], axis=1, inplace=True)

# %%
data_set = data.iloc[:, 0:11]#.values
pd.set_option('display.max_columns', None)

data_set.head(20)
# Out:
#          Open       High        Low  Adj Close        RSI       EMAF  \
# 0   23.089287  23.114286  22.432142  19.046741  35.875684  23.552655
# 1   22.484285  22.692142  22.332144  19.095566  36.765282  23.451416
# 2   22.583929  22.683214  22.280357  19.248705  39.582099  23.376995
# 3   22.691786  23.225000  22.535713  19.704475  47.096862  23.360785
# 4   23.173929  23.313929  23.000000  19.547398  45.028756  23.328499
# 5   22.842501  22.930714  22.500000  19.184416  40.613280  23.258574
# 6   22.537500  22.563213  21.772142  18.493019  33.841003  23.117758
# 7   21.872143  22.692142  21.812857  19.226564  44.383315  23.072631
# 8   22.535713  22.639286  21.846430  18.599760  38.732730  22.961496
# 9   22.194286  22.376785  21.808571  18.704979  40.104305  22.872748
# 10  22.142857  22.214287  21.626785  18.483921  38.180356  22.767656
# 11  21.765356  21.928572  21.107143  18.315926  36.745042  22.653730
# 12  21.245714  21.498571  20.989286  18.052710  34.563812  22.521130
# 13  21.365000  21.535713  21.220358  18.089705  35.143588  22.405308
# 14  21.281786  21.319643  20.526787  17.491104  30.464267  22.233374
# 15  20.840000  20.991785  20.628571  17.728241  34.183829  22.104413
# 16  21.079643  21.097857  20.717501  17.674564  33.746061  21.981714
# 17  20.494286  20.519285  19.848213  16.998289  28.295413  21.786176
# 18  20.022499  20.079643  19.117500  16.381413  24.798298  21.540384
# 19  19.300714  19.817142  19.061428  16.665024  29.113914  21.349667
#
#          EMAM       EMAS    Target  TargetClass  TargetNextClose
# 0   22.673908  21.845652 -3.388720            0        19.095566
# 1   22.670259  21.854182 -3.335224            0        19.248705
# 2   22.670254  21.864988 -2.987310            0        19.704475
# 3   22.680879  21.882760 -3.626532            0        19.547398
# 4   22.687629  21.897846 -3.658085            0        19.184416
# 5   22.685781  21.907071 -4.044481            0        18.493019
# 6   22.667845  21.905388 -2.645578            0        19.226564
# 7   22.667371  21.915170 -3.935953            0        18.599760
# 8   22.652289  21.915044 -3.489307            0        18.704979
# 9   22.639959  21.916562 -3.658936            0        18.483921
# 10  22.622718  21.914611 -3.449430            0        18.315926
# 11  22.601900  21.910066 -3.193005            0        18.052710
# 12  22.575356  21.901475 -3.275295            0        18.089705
# 13  22.550201  21.893574 -3.790682            0        17.491104
# 14  22.511583  21.876441 -3.111759            0        17.728241
# 15  22.479260  21.863234 -3.405079            0        17.674564
# 16  22.446326  21.849364 -3.495996            0        16.998289
# 17  22.396469  21.823923 -3.641087            0        16.381413
# 18  22.333279  21.789240 -2.635691            0        16.665024
# 19  22.277924  21.759420 -3.254904            0        16.536167

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
data_set_scaled = sc.fit_transform(data_set)
print(data_set_scaled)
# Out:
# [[0.05470759 0.05242742 0.05248086 ... 0.34393971 0.         0.04256071]
#  [0.05112291 0.04992461 0.05187615 ... 0.34699367 0.         0.04347489]
#  [0.0517133  0.04987168 0.05156299 ... 0.36685546 0.         0.04619566]
#  ...
#  [0.73420066 0.75496323 0.7448696  ... 0.53574767 0.         0.77219974]
#  [0.75541247 0.76984446 0.76996544 ... 0.61861954 1.         0.79244646]
#  [0.76690706 0.78425145 0.78326921 ... 0.54510587 1.         0.79651942]]

# %%
# multiple feature from data provided to the model
X = []
backcandles = 30
print(data_set_scaled.shape[0])
for j in range(8):#data_set_scaled[0].size):#2 columns are target not X
    X.append([])
    for i in range(backcandles, data_set_scaled.shape[0]):#backcandles+2
        X[j].append(data_set_scaled[i-backcandles:i, j])

#move axis from 0 to position 2
X=np.moveaxis(X, [0], [2])

# Choose -1 for last column, classification else -2...
X, yi =np.array(X), np.array(data_set_scaled[backcandles:,-1])
y=np.reshape(yi,(len(yi),1))

print(X)
print(X.shape)
print(y)
print(y.shape)
# Out:
# 2449
# [[[0.05470759 0.05242742 0.05248086 ... 0.05398809 0.04605846 0.03773333]
#   [0.05112291 0.04992461 0.05187615 ... 0.05335498 0.04603413 0.03779186]
#   [0.0517133  0.04987168 0.05156299 ... 0.05288957 0.0460341  0.037866  ]
#   ...
#   [0.03730265 0.03552402 0.03703896 ... 0.03403626 0.04067667 0.03556804]
#   [0.03792055 0.03650439 0.03833479 ... 0.03406514 0.04048441 0.03546631]
#   [0.03976791 0.04031575 0.04073422 ... 0.03447478 0.04038098 0.03542446]]
#
#  [[0.05112291 0.04992461 0.05187615 ... 0.05335498 0.04603413 0.03779186]
#   [0.0517133  0.04987168 0.05156299 ... 0.05288957 0.0460341  0.037866  ]
#   [0.05235236 0.05308381 0.05310717 ... 0.0527882  0.04610494 0.03798794]
#   ...
#   [0.03792055 0.03650439 0.03833479 ... 0.03406514 0.04048441 0.03546631]
#   [0.03976791 0.04031575 0.04073422 ... 0.03447478 0.04038098 0.03542446]
#   [0.04265638 0.04040468 0.04211427 ... 0.03474437 0.04025721 0.03536773]]
#
#  [[0.0517133  0.04987168 0.05156299 ... 0.05288957 0.0460341  0.037866  ]
#   [0.05235236 0.05308381 0.05310717 ... 0.0527882  0.04610494 0.03798794]
#   [0.0552091  0.05361105 0.05591479 ... 0.0525863  0.04614995 0.03809145]
#   ...
#   [0.03976791 0.04031575 0.04073422 ... 0.03447478 0.04038098 0.03542446]
#   [0.04265638 0.04040468 0.04211427 ... 0.03474437 0.04025721 0.03536773]
#   [0.04005781 0.03942643 0.04042106 ... 0.03494915 0.0401272  0.03530579]]
#
#  ...
#
#  [[0.74670259 0.75525969 0.74287411 ... 0.85881624 0.97163476 0.98552736]
#   [0.74202172 0.74956802 0.71874584 ... 0.85008505 0.96847974 0.98349246]
#   [0.73431909 0.7647457  0.74922357 ... 0.84547305 0.96611605 0.98198616]
#   ...
#   [0.73236389 0.74939016 0.74329736 ... 0.78107337 0.91296115 0.9452119 ]
#   [0.73111959 0.73575393 0.72576059 ... 0.77922812 0.91085312 0.94363192]
#   [0.72395019 0.73972621 0.73718975 ... 0.77887484 0.90907863 0.9422737 ]]
#
#  [[0.74202172 0.74956802 0.71874584 ... 0.85008505 0.96847974 0.98349246]
#   [0.73431909 0.7647457  0.74922357 ... 0.84547305 0.96611605 0.98198616]
#   [0.75221288 0.7570976  0.74728852 ... 0.83966243 0.96343606 0.9802499 ]
#   ...
#   [0.73111959 0.73575393 0.72576059 ... 0.77922812 0.91085312 0.94363192]
#   [0.72395019 0.73972621 0.73718975 ... 0.77887484 0.90907863 0.9422737 ]
#   [0.73420066 0.75496323 0.7448696  ... 0.7801216  0.90768653 0.94117249]]
#
#  [[0.73431909 0.7647457  0.74922357 ... 0.84547305 0.96611605 0.98198616]
#   [0.75221288 0.7570976  0.74728852 ... 0.83966243 0.96343606 0.9802499 ]
#   [0.73811114 0.75603037 0.75339614 ... 0.83450049 0.96083026 0.97855118]
#   ...
#   [0.72395019 0.73972621 0.73718975 ... 0.77887484 0.90907863 0.9422737 ]
#   [0.73420066 0.75496323 0.7448696  ... 0.7801216  0.90768653 0.94117249]
#   [0.75541247 0.76984446 0.76996544 ... 0.78205962 0.90650158 0.94020946]]]
# (2419, 30, 8)
# [[0.03457615]
#  [0.03574364]
#  [0.0350017 ]
#  ...
#  [0.77219974]
#  [0.79244646]
#  [0.79651942]]
# (2419, 1)

# %%
# split data into train test sets
splitlimit = int(len(X)*0.8)
print(splitlimit)
X_train, X_test = X[:splitlimit], X[splitlimit:]
y_train, y_test = y[:splitlimit], y[splitlimit:]
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
print(y_train)
# Out:
# 1935
# (1935, 30, 8)
# (484, 30, 8)
# (1935, 1)
# (484, 1)
# [[0.03457615]
#  [0.03574364]
#  [0.0350017 ]
#  ...
#  [0.56367451]
#  [0.56791598]
#  [0.57023328]]

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import TimeDistributed
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

import tensorflow as tf
import keras
from keras import optimizers
from keras.callbacks import History
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, BatchNormalization
import numpy as np

np.random.seed(10)

# lstm_input = Input(shape=(backcandles, 8), name='lstm_input')
# inputs = LSTM(150, name='first_layer')(lstm_input)
# inputs = Dense(1, name='dense_layer')(inputs)
# output = Activation('linear', name='output')(inputs)
# model = Model(inputs=lstm_input, outputs=output)
# Define the model
lstm_input = Input(shape=(backcandles, 8), name='lstm_input')
x = LSTM(150, name='first_layer', return_sequences=True)(lstm_input)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = LSTM(100, name='second_layer')(x)
x = Dropout(0.2)(x)
x = Dense(50, name='dense_layer1', activation='relu')(x)
output = Dense(1, name='output', activation='linear')(x)

model = Model(inputs=lstm_input, outputs=output)
adam = optimizers.Adam()
model.compile(optimizer=adam, loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])
history = model.fit( X_train,
    y_train,
    batch_size=64,
    epochs=65,
    validation_data=(X_test, y_test),
    verbose=1,)
# Out:
# Epoch 1/65
# 31/31 [==============================] - 10s 182ms/step - loss: 0.0222 - mean_absolute_error: 0.1068 - val_loss: 0.3783 - val_mean_absolute_error: 0.6074
# Epoch 2/65
# 31/31 [==============================] - 3s 111ms/step - loss: 0.0047 - mean_absolute_error: 0.0536 - val_loss: 0.4170 - val_mean_absolute_error: 0.6379
# Epoch 3/65
# 31/31 [==============================] - 3s 113ms/step - loss: 0.0029 - mean_absolute_error: 0.0413 - val_loss: 0.4116 - val_mean_absolute_error: 0.6340
# Epoch 4/65
# 31/31 [==============================] - 4s 131ms/step - loss: 0.0019 - mean_absolute_error: 0.0340 - val_loss: 0.4142 - val_mean_absolute_error: 0.6357
# Epoch 5/65
# 31/31 [==============================] - 4s 137ms/step - loss: 0.0014 - mean_absolute_error: 0.0291 - val_loss: 0.3841 - val_mean_absolute_error: 0.6126
# Epoch 6/65
# 31/31 [==============================] - 3s 111ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 0.3383 - val_mean_absolute_error: 0.5752
# Epoch 7/65
# 31/31 [==============================] - 3s 112ms/step - loss: 9.8072e-04 - mean_absolute_error: 0.0233 - val_loss: 0.3343 - val_mean_absolute_error: 0.5712
# Epoch 8/65
# 31/31 [==============================] - 5s 169ms/step - loss: 8.5929e-04 - mean_absolute_error: 0.0220 - val_loss: 0.3317 - val_mean_absolute_error: 0.5686
# Epoch 9/65
# 31/31 [==============================] - 3s 113ms/step - loss: 9.1081e-04 - mean_absolute_error: 0.0225 - val_loss: 0.2719 - val_mean_absolute_error: 0.5146
# Epoch 10/65
# 31/31 [==============================] - 4s 114ms/step - loss: 7.3523e-04 - mean_absolute_error: 0.0206 - val_loss: 0.2293 - val_mean_absolute_error: 0.4736
# Epoch 11/65
# 31/31 [==============================] - 5s 149ms/step - loss: 8.5305e-04 - mean_absolute_error: 0.0219 - val_loss: 0.2771 - val_mean_absolute_error: 0.5203
# Epoch 12/65
# 31/31 [==============================] - 4s 133ms/step - loss: 7.8899e-04 - mean_absolute_error: 0.0209 - val_loss: 0.1965 - val_mean_absolute_error: 0.4376
# Epoch 13/65
# 31/31 [==============================] - 3s 112ms/step - loss: 6.4290e-04 - mean_absolute_error: 0.0189 - val_loss: 0.1839 - val_mean_absolute_error: 0.4216
# Epoch 14/65
# 31/31 [==============================] - 4s 114ms/step - loss: 6.0963e-04 - mean_absolute_error: 0.0184 - val_loss: 0.1609 - val_mean_absolute_error: 0.3940
# Epoch 15/65
# 31/31 [==============================] - 5s 168ms/step - loss: 7.6445e-04 - mean_absolute_error: 0.0209 - val_loss: 0.1231 - val_mean_absolute_error: 0.3436
# Epoch 16/65
# 31/31 [==============================] - 3s 113ms/step - loss: 5.7513e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0857 - val_mean_absolute_error: 0.2880
# Epoch 17/65
# 31/31 [==============================] - 4s 116ms/step - loss: 6.2227e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0967 - val_mean_absolute_error: 0.3052
# Epoch 18/65
# 31/31 [==============================] - 5s 165ms/step - loss: 5.2706e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0705 - val_mean_absolute_error: 0.2572
# Epoch 19/65
# 31/31 [==============================] - 4s 115ms/step - loss: 5.2515e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0430 - val_mean_absolute_error: 0.1968
# Epoch 20/65
# 31/31 [==============================] - 4s 114ms/step - loss: 5.6079e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0482 - val_mean_absolute_error: 0.2090
# Epoch 21/65
# 31/31 [==============================] - 4s 127ms/step - loss: 5.2615e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0839 - val_mean_absolute_error: 0.2674
# Epoch 22/65
# 31/31 [==============================] - 5s 146ms/step - loss: 5.3083e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0893 - val_mean_absolute_error: 0.2839
# Epoch 23/65
# 31/31 [==============================] - 4s 114ms/step - loss: 4.3182e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0824 - val_mean_absolute_error: 0.2623
# Epoch 24/65
# 31/31 [==============================] - 4s 116ms/step - loss: 6.8511e-04 - mean_absolute_error: 0.0188 - val_loss: 0.1300 - val_mean_absolute_error: 0.3397
# Epoch 25/65
# 31/31 [==============================] - 5s 168ms/step - loss: 4.1975e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0426 - val_mean_absolute_error: 0.1944
# Epoch 26/65
# 31/31 [==============================] - 4s 115ms/step - loss: 4.7230e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0060 - val_mean_absolute_error: 0.0646
# Epoch 27/65
# 31/31 [==============================] - 3s 113ms/step - loss: 4.8293e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0630 - val_mean_absolute_error: 0.2306
# Epoch 28/65
# 31/31 [==============================] - 5s 156ms/step - loss: 5.1841e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0439 - val_mean_absolute_error: 0.1927
# Epoch 29/65
# 31/31 [==============================] - 4s 118ms/step - loss: 4.8234e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0439 - val_mean_absolute_error: 0.1943
# Epoch 30/65
# 31/31 [==============================] - 4s 114ms/step - loss: 4.2412e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0223 - val_mean_absolute_error: 0.1335
# Epoch 31/65
# 31/31 [==============================] - 4s 126ms/step - loss: 3.6465e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0258 - val_mean_absolute_error: 0.1491
# Epoch 32/65
# 31/31 [==============================] - 5s 150ms/step - loss: 4.0794e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0184 - val_mean_absolute_error: 0.1220
# Epoch 33/65
# 31/31 [==============================] - 4s 115ms/step - loss: 3.8078e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0038 - val_mean_absolute_error: 0.0497
# Epoch 34/65
# 31/31 [==============================] - 4s 117ms/step - loss: 3.4037e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0133 - val_mean_absolute_error: 0.0873
# Epoch 35/65
# 31/31 [==============================] - 6s 184ms/step - loss: 4.8708e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0144 - val_mean_absolute_error: 0.1050
# Epoch 36/65
# 31/31 [==============================] - 7s 233ms/step - loss: 4.9157e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0248 - val_mean_absolute_error: 0.1444
# Epoch 37/65
# 31/31 [==============================] - 5s 164ms/step - loss: 4.9355e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0515 - val_mean_absolute_error: 0.2046
# Epoch 38/65
# 31/31 [==============================] - 4s 114ms/step - loss: 4.1333e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0207 - val_mean_absolute_error: 0.1270
# Epoch 39/65
# 31/31 [==============================] - 4s 115ms/step - loss: 3.3941e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0287 - val_mean_absolute_error: 0.1488
# Epoch 40/65
# 31/31 [==============================] - 4s 133ms/step - loss: 3.5788e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0320 - val_mean_absolute_error: 0.1633
# Epoch 41/65
# 31/31 [==============================] - 4s 142ms/step - loss: 3.2694e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0504 - val_mean_absolute_error: 0.2047
# Epoch 42/65
# 31/31 [==============================] - 3s 113ms/step - loss: 3.5426e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0282 - val_mean_absolute_error: 0.1540
# Epoch 43/65
# 31/31 [==============================] - 4s 115ms/step - loss: 4.7065e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0074 - val_mean_absolute_error: 0.0732
# Epoch 44/65
# 31/31 [==============================] - 5s 170ms/step - loss: 3.8840e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0166 - val_mean_absolute_error: 0.1219
# Epoch 45/65
# 31/31 [==============================] - 4s 117ms/step - loss: 4.0907e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0148 - val_mean_absolute_error: 0.1108
# Epoch 46/65
# 31/31 [==============================] - 4s 114ms/step - loss: 3.6510e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0220 - val_mean_absolute_error: 0.1269
# Epoch 47/65
# 31/31 [==============================] - 5s 156ms/step - loss: 3.5881e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0433 - val_mean_absolute_error: 0.1739
# Epoch 48/65
# 31/31 [==============================] - 4s 117ms/step - loss: 4.7478e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0302 - val_mean_absolute_error: 0.1645
# Epoch 49/65
# 31/31 [==============================] - 4s 114ms/step - loss: 4.3740e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0725 - val_mean_absolute_error: 0.2573
# Epoch 50/65
# 31/31 [==============================] - 4s 127ms/step - loss: 3.5386e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0353 - val_mean_absolute_error: 0.1723
# Epoch 51/65
# 31/31 [==============================] - 5s 146ms/step - loss: 4.0709e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0260 - val_mean_absolute_error: 0.1385
# Epoch 52/65
# 31/31 [==============================] - 3s 113ms/step - loss: 2.8918e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0163 - val_mean_absolute_error: 0.1117
# Epoch 53/65
# 31/31 [==============================] - 3s 111ms/step - loss: 4.4682e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0133 - val_mean_absolute_error: 0.1009
# Epoch 54/65
# 31/31 [==============================] - 5s 171ms/step - loss: 3.5495e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0218 - val_mean_absolute_error: 0.1401
# Epoch 55/65
# 31/31 [==============================] - 4s 114ms/step - loss: 2.7265e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0079 - val_mean_absolute_error: 0.0721
# Epoch 56/65
# 31/31 [==============================] - 4s 114ms/step - loss: 3.5650e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0324 - val_mean_absolute_error: 0.1291
# Epoch 57/65
# 31/31 [==============================] - 5s 155ms/step - loss: 2.9279e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0155 - val_mean_absolute_error: 0.1148
# Epoch 58/65
# 31/31 [==============================] - 4s 118ms/step - loss: 2.3946e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0328 - val_mean_absolute_error: 0.1674
# Epoch 59/65
# 31/31 [==============================] - 4s 116ms/step - loss: 2.8415e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0225 - val_mean_absolute_error: 0.1356
# Epoch 60/65
# 31/31 [==============================] - 4s 125ms/step - loss: 3.5368e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0198 - val_mean_absolute_error: 0.1320
# Epoch 61/65
# 31/31 [==============================] - 5s 156ms/step - loss: 2.8958e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0085 - val_mean_absolute_error: 0.0856
# Epoch 62/65
# 31/31 [==============================] - 4s 115ms/step - loss: 3.6966e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0053 - val_mean_absolute_error: 0.0622
# Epoch 63/65
# 31/31 [==============================] - 4s 113ms/step - loss: 2.6850e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0089 - val_mean_absolute_error: 0.0838
# Epoch 64/65
# 31/31 [==============================] - 5s 160ms/step - loss: 3.1671e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0090 - val_mean_absolute_error: 0.0854
# Epoch 65/65
# 31/31 [==============================] - 4s 115ms/step - loss: 2.7167e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0080 - val_mean_absolute_error: 0.0807

# %%
# Convert training history to datafram for viewing and graphing.
hist = pd.DataFrame(history.history)
hist.head()
# Out:
#        loss  mean_absolute_error  val_loss  val_mean_absolute_error
# 0  0.022243             0.106808  0.378345                 0.607412
# 1  0.004709             0.053610  0.417041                 0.637943
# 2  0.002851             0.041286  0.411599                 0.634029
# 3  0.001908             0.034028  0.414200                 0.635658
# 4  0.001446             0.029133  0.384064                 0.612606

# %%
# Training errors with respect to ecochs.
# loss: values of the cost function for training data.
# val_loss: values of the cost function for cross-validation data.
hist.plot()
# Out:
# <Axes: >

# %%
y_pred = model.predict(X_test)
for i in range(10):
    print(y_pred[i], y_test[i])
# Out:
# 16/16 [==============================] - 1s 24ms/step
# [0.51092124] [0.5926206]
# [0.5168519] [0.57752273]
# [0.5235267] [0.58695527]
# [0.5261587] [0.56737486]
# [0.5297839] [0.58860516]
# [0.5299736] [0.60028624]
# [0.5330251] [0.5996876]
# [0.53706896] [0.59793541]
# [0.54000086] [0.60351316]
# [0.5424188] [0.60435992]

# %%
plt.figure(figsize=(16,8))
plt.plot(y_test, color = 'black', label = 'Test')
plt.plot(y_pred, color = 'green', label = 'pred')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) score
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2) score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.0807
# Mean Squared Error (MSE): 0.0080
# Root Mean Squared Error (RMSE): 0.0894
# R-squared (R2) score: 0.3827

# %%
# Scatter plot of actual vs. predicted adjacent closing prices
plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

# Plot actual values as orange circles with larger markers
plt.scatter(y_test, y_test, color='orange', label='Actual Adjacent Closing Price', alpha=0.7, s=60)

# Plot predicted values as black crosses with smaller markers
plt.scatter(y_test, y_pred, color='green', label='Predicted Adjacent Closing Price', alpha=0.7, s=40, marker='x')

# Plot the diagonal line for perfect predictions
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--', label='Perfect Prediction')

plt.xlabel('Actual Adjacent Closing Price')
plt.ylabel('Predicted Adjacent Closing Price')
plt.title('Scatter Plot of Actual vs. Predicted Adjacent Closing Price')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
# Histogram of prediction errors
errors = y_test - y_pred

plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

plt.hist(errors, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Histogram of Prediction Errors')

# Add grid lines for better readability
plt.grid(True)

plt.show()
