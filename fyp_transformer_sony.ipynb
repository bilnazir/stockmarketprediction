# %% [markdown]
# <a href="https://colab.research.google.com/github/bilnazir/stockmarketprediction/blob/main/fyp_transformer_sony.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas-ta
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas-ta) (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=2742ae9f5d04e66ee5b4f630e889297d6d4c7a685755fd7e6420bbcdb6c8073b
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
import yfinance as yf

# %%
# Load historical stock data (date, closing price) into a pandas DataFrame
df = yf.download(tickers=['SONY'], start='2012-01-01', end='2022-06-20')
data = df.dropna()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2633 entries, 2012-01-03 to 2022-06-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2633 non-null   float64
#  1   High       2633 non-null   float64
#  2   Low        2633 non-null   float64
#  3   Close      2633 non-null   float64
#  4   Adj Close  2633 non-null   float64
#  5   Volume     2633 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 144.0 KB

# %%
data
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2012-01-03  18.280001  18.500000  18.280001  18.379999  18.379999  1414800
# 2012-01-04  18.240000  18.270000  18.139999  18.219999  18.219999  1146400
# 2012-01-05  17.830000  17.850000  17.600000  17.700001  17.700001  1464900
# 2012-01-06  17.570000  17.570000  17.370001  17.440001  17.440001   594100
# 2012-01-09  17.510000  17.510000  17.350000  17.469999  17.469999   529400
# ...               ...        ...        ...        ...        ...      ...
# 2022-06-13  85.000000  85.430000  83.550003  83.930000  83.930000   772600
# 2022-06-14  83.300003  83.470001  81.900002  83.000000  83.000000   931000
# 2022-06-15  83.220001  85.050003  82.599998  84.339996  84.339996   633600
# 2022-06-16  82.360001  82.720001  81.220001  81.660004  81.660004  1178600
# 2022-06-17  83.129997  84.459999  82.820000  84.000000  84.000000   828700
#
# [2633 rows x 6 columns]

# %%
data.shape
# Out:
# (2633, 6)

# %%
# Adding indicators
import pandas_ta as ta
data['RSI'] = ta.rsi(data.Close, length=15)
data['EMAF'] = ta.ema(data.Close, length=20)
data['EMAM'] = ta.ema(data.Close, length=100)
data['EMAS'] = ta.ema(data.Close, length=150)

data['Target'] = data['Adj Close'] - data.Open
data['Target'] = data['Target'].shift(-1)

data['TargetClass'] = [1 if data.Target[i] > 0 else 0 for i in range(len(data))]

data['TargetNextClose'] = data['Adj Close'].shift(-1)

data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Volume', 'Close','Date'], axis=1, inplace=True)
# Out:
# <ipython-input-8-8a8148f44cbd>:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data['TargetClass'] = [1 if data.Target[i] > 0 else 0 for i in range(len(data))]

# %%
data_set = data.iloc[:, 0:11]
pd.set_option('display.max_columns', None)

data_set.head(20)
# Out:
#      Open   High    Low  Adj Close        RSI       EMAF       EMAM  \
# 0   11.46  11.64  11.46      11.51  38.879619  12.177784  14.851434
# 1   11.64  11.74  11.61      11.67  41.082498  12.129424  14.788435
# 2   11.58  11.74  11.58      11.71  41.645850  12.089479  14.727476
# 3   11.73  12.01  11.72      11.98  45.420133  12.079052  14.673071
# 4   12.02  12.40  11.98      12.34  50.036683  12.103904  14.626871
# 5   12.12  12.29  12.12      12.21  48.451088  12.114009  14.579012
# 6   11.79  11.81  11.66      11.71  42.854883  12.075532  14.522200
# 7   11.32  11.40  11.26      11.39  39.709811  12.010243  14.460176
# 8   11.66  11.86  11.65      11.84  45.712628  11.994029  14.408292
# 9   11.96  11.98  11.90      11.95  47.092281  11.989836  14.359613
# 10  11.94  12.03  11.89      12.00  47.739113  11.990804  14.312888
# 11  12.01  12.10  11.88      11.95  47.121867  11.986918  14.266098
# 12  11.77  11.84  11.68      11.79  45.121639  11.968164  14.217066
# 13  11.78  11.79  11.59      11.61  42.925358  11.934053  14.165441
# 14  11.56  11.79  11.53      11.71  44.532424  11.912715  14.116819
# 15  11.72  11.73  11.63      11.64  43.611447  11.886742  14.067773
# 16  11.52  11.56  11.48      11.49  41.634540  11.848957  14.016728
# 17  11.77  11.80  11.69      11.73  45.842985  11.837628  13.971446
# 18  11.53  11.55  11.41      11.43  41.805832  11.798806  13.921120
# 19  11.34  11.41  11.25      11.31  40.285377  11.752253  13.869415
#
#          EMAS    Target  TargetClass  TargetNextClose
# 0   16.593267  0.030000            1            11.67
# 1   16.528058  0.130000            1            11.71
# 2   16.464243  0.250000            1            11.98
# 3   16.404849  0.320000            1            12.34
# 4   16.351010  0.090000            1            12.21
# 5   16.296162 -0.080000            0            11.71
# 6   16.235418  0.070001            1            11.39
# 7   16.171240  0.180000            1            11.84
# 8   16.113873 -0.010000            0            11.95
# 9   16.058722  0.060000            1            12.00
# 10  16.004964 -0.060000            0            11.95
# 11  15.951256  0.020000            1            11.79
# 12  15.896140 -0.170000            0            11.61
# 13  15.839370  0.150000            1            11.71
# 14  15.784676 -0.080000            0            11.64
# 15  15.729780 -0.030001            0            11.49
# 16  15.673624 -0.040001            0            11.73
# 17  15.621391 -0.099999            0            11.43
# 18  15.565875 -0.030000            0            11.31
# 19  15.509506 -0.030000            0            11.30

# %%
import matplotlib.pyplot as plt
data_set_AC=data_set['Adj Close']
plt.ylabel('Up-Down Movemetn')
plt.xlabel('Date')
plt.plot(data_set_AC)

# %%
# Normalize the data
sc = MinMaxScaler(feature_range=(0, 1))
data_set_scaled = sc.fit_transform(data)

# %%
# Prepare the data for training
X, y = [], []
backcandles = 20
for i in range(backcandles, data_set_scaled.shape[0]):
    X.append(data_set_scaled[i - backcandles:i, :-1])
    y.append(data_set_scaled[i, -1])

X, y = np.array(X), np.array(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Build the Transformer model
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-head self-attention mechanism
    attn_output = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    attn_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)

    # Feed-forward neural network
    ffn_output = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(attn_output)
    ffn_output = tf.keras.layers.Dropout(dropout)(ffn_output)
    ffn_output = tf.keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(ffn_output)
    return tf.keras.layers.LayerNormalization(epsilon=1e-6)(attn_output + ffn_output)

# %%
# Build the Transformer model
def build_transformer_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
):
    inputs = Input(shape=input_shape)

    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = tf.keras.layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = Dense(dim, activation="relu")(x)
        x = Dropout(dropout)(x)
    outputs = Dense(1)(x)

    return Model(inputs, outputs)

# %%
input_shape = X_train.shape[1:]
head_size = 128
num_heads = 4
ff_dim = 32
num_transformer_blocks = 8
mlp_units = [64, 32]

# %%
# Create and compile the Transformer model
model = build_transformer_model(
    input_shape,
    head_size=head_size,
    num_heads=num_heads,
    ff_dim=ff_dim,
    num_transformer_blocks=num_transformer_blocks,
    mlp_units=mlp_units,
    dropout=0.25,
)

model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

# %%
# Training the model
history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=128,
    validation_data=(X_test, y_test),
    verbose=1,
)
# Out:
# Epoch 1/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 503ms/step - loss: 0.1432 - mean_absolute_error: 0.2724 - val_loss: 0.0110 - val_mean_absolute_error: 0.0829
# Epoch 2/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 414ms/step - loss: 0.0317 - mean_absolute_error: 0.1335 - val_loss: 0.0049 - val_mean_absolute_error: 0.0547
# Epoch 3/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 331ms/step - loss: 0.0236 - mean_absolute_error: 0.1142 - val_loss: 0.0048 - val_mean_absolute_error: 0.0571
# Epoch 4/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 357ms/step - loss: 0.0162 - mean_absolute_error: 0.0915 - val_loss: 0.0141 - val_mean_absolute_error: 0.0997
# Epoch 5/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 391ms/step - loss: 0.0148 - mean_absolute_error: 0.0922 - val_loss: 0.0024 - val_mean_absolute_error: 0.0395
# Epoch 6/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 400ms/step - loss: 0.0139 - mean_absolute_error: 0.0845 - val_loss: 0.0073 - val_mean_absolute_error: 0.0734
# Epoch 7/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 350ms/step - loss: 0.0102 - mean_absolute_error: 0.0736 - val_loss: 0.0095 - val_mean_absolute_error: 0.0826
# Epoch 8/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 391ms/step - loss: 0.0102 - mean_absolute_error: 0.0722 - val_loss: 0.0052 - val_mean_absolute_error: 0.0621
# Epoch 9/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - loss: 0.0094 - mean_absolute_error: 0.0694 - val_loss: 0.0036 - val_mean_absolute_error: 0.0497
# Epoch 10/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 400ms/step - loss: 0.0086 - mean_absolute_error: 0.0685 - val_loss: 0.0038 - val_mean_absolute_error: 0.0410
# Epoch 11/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - loss: 0.0096 - mean_absolute_error: 0.0719 - val_loss: 0.0022 - val_mean_absolute_error: 0.0376
# Epoch 12/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 373ms/step - loss: 0.0071 - mean_absolute_error: 0.0597 - val_loss: 0.0044 - val_mean_absolute_error: 0.0566
# Epoch 13/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 395ms/step - loss: 0.0076 - mean_absolute_error: 0.0627 - val_loss: 0.0027 - val_mean_absolute_error: 0.0435
# Epoch 14/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 328ms/step - loss: 0.0078 - mean_absolute_error: 0.0594 - val_loss: 0.0041 - val_mean_absolute_error: 0.0535
# Epoch 15/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 345ms/step - loss: 0.0073 - mean_absolute_error: 0.0593 - val_loss: 0.0034 - val_mean_absolute_error: 0.0491
# Epoch 16/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 401ms/step - loss: 0.0065 - mean_absolute_error: 0.0545 - val_loss: 0.0042 - val_mean_absolute_error: 0.0550
# Epoch 17/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 404ms/step - loss: 0.0076 - mean_absolute_error: 0.0632 - val_loss: 0.0019 - val_mean_absolute_error: 0.0333
# Epoch 18/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - loss: 0.0063 - mean_absolute_error: 0.0531 - val_loss: 0.0022 - val_mean_absolute_error: 0.0382
# Epoch 19/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - loss: 0.0057 - mean_absolute_error: 0.0515 - val_loss: 0.0024 - val_mean_absolute_error: 0.0398
# Epoch 20/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 368ms/step - loss: 0.0063 - mean_absolute_error: 0.0536 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 21/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 403ms/step - loss: 0.0051 - mean_absolute_error: 0.0484 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 22/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 338ms/step - loss: 0.0051 - mean_absolute_error: 0.0504 - val_loss: 0.0042 - val_mean_absolute_error: 0.0500
# Epoch 23/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 382ms/step - loss: 0.0068 - mean_absolute_error: 0.0564 - val_loss: 0.0024 - val_mean_absolute_error: 0.0404
# Epoch 24/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 403ms/step - loss: 0.0048 - mean_absolute_error: 0.0492 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 25/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 356ms/step - loss: 0.0047 - mean_absolute_error: 0.0490 - val_loss: 0.0016 - val_mean_absolute_error: 0.0326
# Epoch 26/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 410ms/step - loss: 0.0052 - mean_absolute_error: 0.0488 - val_loss: 0.0045 - val_mean_absolute_error: 0.0552
# Epoch 27/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - loss: 0.0056 - mean_absolute_error: 0.0559 - val_loss: 0.0026 - val_mean_absolute_error: 0.0421
# Epoch 28/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 394ms/step - loss: 0.0052 - mean_absolute_error: 0.0506 - val_loss: 9.0098e-04 - val_mean_absolute_error: 0.0220
# Epoch 29/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 402ms/step - loss: 0.0056 - mean_absolute_error: 0.0528 - val_loss: 0.0035 - val_mean_absolute_error: 0.0488
# Epoch 30/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 333ms/step - loss: 0.0051 - mean_absolute_error: 0.0502 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 31/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 369ms/step - loss: 0.0049 - mean_absolute_error: 0.0484 - val_loss: 0.0015 - val_mean_absolute_error: 0.0302
# Epoch 32/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 402ms/step - loss: 0.0051 - mean_absolute_error: 0.0485 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 33/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 387ms/step - loss: 0.0041 - mean_absolute_error: 0.0438 - val_loss: 8.7265e-04 - val_mean_absolute_error: 0.0224
# Epoch 34/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - loss: 0.0040 - mean_absolute_error: 0.0433 - val_loss: 0.0020 - val_mean_absolute_error: 0.0380
# Epoch 35/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 397ms/step - loss: 0.0042 - mean_absolute_error: 0.0447 - val_loss: 0.0014 - val_mean_absolute_error: 0.0300
# Epoch 36/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 359ms/step - loss: 0.0046 - mean_absolute_error: 0.0472 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 37/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 367ms/step - loss: 0.0038 - mean_absolute_error: 0.0422 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 38/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 399ms/step - loss: 0.0042 - mean_absolute_error: 0.0436 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 39/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 356ms/step - loss: 0.0043 - mean_absolute_error: 0.0461 - val_loss: 0.0016 - val_mean_absolute_error: 0.0320
# Epoch 40/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - loss: 0.0041 - mean_absolute_error: 0.0440 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 41/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - loss: 0.0046 - mean_absolute_error: 0.0480 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 42/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - loss: 0.0042 - mean_absolute_error: 0.0442 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 43/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 372ms/step - loss: 0.0043 - mean_absolute_error: 0.0445 - val_loss: 8.7538e-04 - val_mean_absolute_error: 0.0226
# Epoch 44/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 403ms/step - loss: 0.0032 - mean_absolute_error: 0.0404 - val_loss: 0.0011 - val_mean_absolute_error: 0.0239
# Epoch 45/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - loss: 0.0038 - mean_absolute_error: 0.0432 - val_loss: 0.0024 - val_mean_absolute_error: 0.0398
# Epoch 46/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - loss: 0.0050 - mean_absolute_error: 0.0513 - val_loss: 0.0013 - val_mean_absolute_error: 0.0289
# Epoch 47/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - loss: 0.0045 - mean_absolute_error: 0.0455 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 48/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 383ms/step - loss: 0.0035 - mean_absolute_error: 0.0413 - val_loss: 8.8655e-04 - val_mean_absolute_error: 0.0238
# Epoch 49/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 413ms/step - loss: 0.0037 - mean_absolute_error: 0.0419 - val_loss: 0.0015 - val_mean_absolute_error: 0.0318
# Epoch 50/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 333ms/step - loss: 0.0036 - mean_absolute_error: 0.0416 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266
# Epoch 51/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 406ms/step - loss: 0.0036 - mean_absolute_error: 0.0420 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 52/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - loss: 0.0039 - mean_absolute_error: 0.0426 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282
# Epoch 53/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - loss: 0.0037 - mean_absolute_error: 0.0430 - val_loss: 8.6574e-04 - val_mean_absolute_error: 0.0228
# Epoch 54/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - loss: 0.0039 - mean_absolute_error: 0.0426 - val_loss: 9.2633e-04 - val_mean_absolute_error: 0.0223
# Epoch 55/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 333ms/step - loss: 0.0041 - mean_absolute_error: 0.0439 - val_loss: 0.0022 - val_mean_absolute_error: 0.0387
# Epoch 56/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 409ms/step - loss: 0.0050 - mean_absolute_error: 0.0516 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 57/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0035 - mean_absolute_error: 0.0416 - val_loss: 0.0013 - val_mean_absolute_error: 0.0250
# Epoch 58/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - loss: 0.0048 - mean_absolute_error: 0.0464 - val_loss: 0.0017 - val_mean_absolute_error: 0.0326
# Epoch 59/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 404ms/step - loss: 0.0036 - mean_absolute_error: 0.0421 - val_loss: 5.8271e-04 - val_mean_absolute_error: 0.0185
# Epoch 60/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - loss: 0.0033 - mean_absolute_error: 0.0415 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 61/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 404ms/step - loss: 0.0037 - mean_absolute_error: 0.0419 - val_loss: 0.0010 - val_mean_absolute_error: 0.0259
# Epoch 62/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 405ms/step - loss: 0.0032 - mean_absolute_error: 0.0395 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 63/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 400ms/step - loss: 0.0030 - mean_absolute_error: 0.0379 - val_loss: 7.4086e-04 - val_mean_absolute_error: 0.0196
# Epoch 64/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 407ms/step - loss: 0.0036 - mean_absolute_error: 0.0409 - val_loss: 0.0014 - val_mean_absolute_error: 0.0320
# Epoch 65/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 420ms/step - loss: 0.0039 - mean_absolute_error: 0.0427 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 66/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 333ms/step - loss: 0.0034 - mean_absolute_error: 0.0402 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 67/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 371ms/step - loss: 0.0034 - mean_absolute_error: 0.0393 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291
# Epoch 68/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 410ms/step - loss: 0.0047 - mean_absolute_error: 0.0452 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268
# Epoch 69/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 354ms/step - loss: 0.0036 - mean_absolute_error: 0.0427 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 70/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 359ms/step - loss: 0.0035 - mean_absolute_error: 0.0416 - val_loss: 9.9993e-04 - val_mean_absolute_error: 0.0258
# Epoch 71/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 406ms/step - loss: 0.0033 - mean_absolute_error: 0.0386 - val_loss: 7.0977e-04 - val_mean_absolute_error: 0.0196
# Epoch 72/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 405ms/step - loss: 0.0036 - mean_absolute_error: 0.0428 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 73/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 377ms/step - loss: 0.0037 - mean_absolute_error: 0.0430 - val_loss: 8.5374e-04 - val_mean_absolute_error: 0.0236
# Epoch 74/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - loss: 0.0040 - mean_absolute_error: 0.0448 - val_loss: 0.0018 - val_mean_absolute_error: 0.0284
# Epoch 75/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 334ms/step - loss: 0.0036 - mean_absolute_error: 0.0429 - val_loss: 9.1250e-04 - val_mean_absolute_error: 0.0233
# Epoch 76/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 393ms/step - loss: 0.0037 - mean_absolute_error: 0.0423 - val_loss: 9.2770e-04 - val_mean_absolute_error: 0.0251
# Epoch 77/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - loss: 0.0033 - mean_absolute_error: 0.0403 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313
# Epoch 78/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 480ms/step - loss: 0.0033 - mean_absolute_error: 0.0403 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282
# Epoch 79/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 402ms/step - loss: 0.0036 - mean_absolute_error: 0.0406 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 80/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 371ms/step - loss: 0.0030 - mean_absolute_error: 0.0387 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 81/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - loss: 0.0035 - mean_absolute_error: 0.0419 - val_loss: 0.0014 - val_mean_absolute_error: 0.0313
# Epoch 82/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 404ms/step - loss: 0.0037 - mean_absolute_error: 0.0423 - val_loss: 0.0016 - val_mean_absolute_error: 0.0334
# Epoch 83/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 406ms/step - loss: 0.0040 - mean_absolute_error: 0.0426 - val_loss: 9.1063e-04 - val_mean_absolute_error: 0.0244
# Epoch 84/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - loss: 0.0032 - mean_absolute_error: 0.0379 - val_loss: 0.0011 - val_mean_absolute_error: 0.0230
# Epoch 85/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - loss: 0.0033 - mean_absolute_error: 0.0407 - val_loss: 0.0011 - val_mean_absolute_error: 0.0218
# Epoch 86/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 406ms/step - loss: 0.0032 - mean_absolute_error: 0.0385 - val_loss: 9.7292e-04 - val_mean_absolute_error: 0.0248
# Epoch 87/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - loss: 0.0036 - mean_absolute_error: 0.0423 - val_loss: 6.8164e-04 - val_mean_absolute_error: 0.0205
# Epoch 88/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - loss: 0.0030 - mean_absolute_error: 0.0380 - val_loss: 5.4090e-04 - val_mean_absolute_error: 0.0174
# Epoch 89/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 406ms/step - loss: 0.0033 - mean_absolute_error: 0.0393 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 90/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - loss: 0.0032 - mean_absolute_error: 0.0394 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 91/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 379ms/step - loss: 0.0035 - mean_absolute_error: 0.0403 - val_loss: 8.1137e-04 - val_mean_absolute_error: 0.0223
# Epoch 92/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - loss: 0.0033 - mean_absolute_error: 0.0396 - val_loss: 0.0015 - val_mean_absolute_error: 0.0329
# Epoch 93/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 334ms/step - loss: 0.0035 - mean_absolute_error: 0.0420 - val_loss: 0.0022 - val_mean_absolute_error: 0.0374
# Epoch 94/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 398ms/step - loss: 0.0038 - mean_absolute_error: 0.0432 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 95/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 412ms/step - loss: 0.0034 - mean_absolute_error: 0.0396 - val_loss: 8.7043e-04 - val_mean_absolute_error: 0.0244
# Epoch 96/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - loss: 0.0036 - mean_absolute_error: 0.0418 - val_loss: 0.0011 - val_mean_absolute_error: 0.0269
# Epoch 97/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - loss: 0.0030 - mean_absolute_error: 0.0384 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 98/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 372ms/step - loss: 0.0027 - mean_absolute_error: 0.0372 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 99/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 405ms/step - loss: 0.0038 - mean_absolute_error: 0.0437 - val_loss: 8.7213e-04 - val_mean_absolute_error: 0.0224
# Epoch 100/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 344ms/step - loss: 0.0031 - mean_absolute_error: 0.0392 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 101/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - loss: 0.0036 - mean_absolute_error: 0.0412 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 102/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - loss: 0.0028 - mean_absolute_error: 0.0372 - val_loss: 8.0942e-04 - val_mean_absolute_error: 0.0226
# Epoch 103/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 367ms/step - loss: 0.0027 - mean_absolute_error: 0.0367 - val_loss: 0.0010 - val_mean_absolute_error: 0.0258
# Epoch 104/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - loss: 0.0034 - mean_absolute_error: 0.0399 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 105/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - loss: 0.0029 - mean_absolute_error: 0.0384 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 106/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 367ms/step - loss: 0.0035 - mean_absolute_error: 0.0425 - val_loss: 0.0022 - val_mean_absolute_error: 0.0379
# Epoch 107/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 355ms/step - loss: 0.0029 - mean_absolute_error: 0.0383 - val_loss: 0.0017 - val_mean_absolute_error: 0.0349
# Epoch 108/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 404ms/step - loss: 0.0037 - mean_absolute_error: 0.0434 - val_loss: 0.0023 - val_mean_absolute_error: 0.0402
# Epoch 109/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - loss: 0.0033 - mean_absolute_error: 0.0407 - val_loss: 8.7225e-04 - val_mean_absolute_error: 0.0241
# Epoch 110/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 403ms/step - loss: 0.0029 - mean_absolute_error: 0.0382 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 111/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - loss: 0.0033 - mean_absolute_error: 0.0404 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 112/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - loss: 0.0030 - mean_absolute_error: 0.0375 - val_loss: 7.0457e-04 - val_mean_absolute_error: 0.0207
# Epoch 113/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - loss: 0.0030 - mean_absolute_error: 0.0385 - val_loss: 0.0010 - val_mean_absolute_error: 0.0274
# Epoch 114/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 374ms/step - loss: 0.0025 - mean_absolute_error: 0.0366 - val_loss: 9.2820e-04 - val_mean_absolute_error: 0.0238
# Epoch 115/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - loss: 0.0031 - mean_absolute_error: 0.0402 - val_loss: 0.0017 - val_mean_absolute_error: 0.0343
# Epoch 116/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 331ms/step - loss: 0.0033 - mean_absolute_error: 0.0394 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 117/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 406ms/step - loss: 0.0029 - mean_absolute_error: 0.0363 - val_loss: 8.7338e-04 - val_mean_absolute_error: 0.0247
# Epoch 118/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 404ms/step - loss: 0.0031 - mean_absolute_error: 0.0394 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 119/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - loss: 0.0033 - mean_absolute_error: 0.0390 - val_loss: 0.0017 - val_mean_absolute_error: 0.0337
# Epoch 120/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0033 - mean_absolute_error: 0.0417 - val_loss: 0.0027 - val_mean_absolute_error: 0.0426
# Epoch 121/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 368ms/step - loss: 0.0032 - mean_absolute_error: 0.0409 - val_loss: 6.7632e-04 - val_mean_absolute_error: 0.0188
# Epoch 122/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 398ms/step - loss: 0.0029 - mean_absolute_error: 0.0378 - val_loss: 9.7306e-04 - val_mean_absolute_error: 0.0265
# Epoch 123/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 404ms/step - loss: 0.0029 - mean_absolute_error: 0.0387 - val_loss: 0.0011 - val_mean_absolute_error: 0.0284
# Epoch 124/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - loss: 0.0029 - mean_absolute_error: 0.0382 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 125/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 413ms/step - loss: 0.0028 - mean_absolute_error: 0.0362 - val_loss: 0.0014 - val_mean_absolute_error: 0.0314
# Epoch 126/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 399ms/step - loss: 0.0027 - mean_absolute_error: 0.0370 - val_loss: 0.0017 - val_mean_absolute_error: 0.0338
# Epoch 127/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 412ms/step - loss: 0.0031 - mean_absolute_error: 0.0390 - val_loss: 0.0014 - val_mean_absolute_error: 0.0308
# Epoch 128/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 435ms/step - loss: 0.0028 - mean_absolute_error: 0.0364 - val_loss: 0.0013 - val_mean_absolute_error: 0.0296

# %%
# Convert training history to datafram for viewing and graphing.
hist = pd.DataFrame(history.history)
hist.head()
# Out:
#        loss  mean_absolute_error  val_loss  val_mean_absolute_error
# 0  0.079954             0.209317  0.010982                 0.082929
# 1  0.028871             0.127263  0.004891                 0.054680
# 2  0.021509             0.107963  0.004773                 0.057058
# 3  0.016302             0.092156  0.014083                 0.099657
# 4  0.014526             0.088536  0.002398                 0.039505

# %%
# Training errors with respect to ecochs.
# loss: values of the cost function for training data.
# val_loss: values of the cost function for cross-validation data.
hist.plot()
# Out:
# <Axes: >

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 20, 10)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 20, 10)         │         22,026 │ input_layer[0][0],     │
# │ (MultiHeadAttention)      │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 20, 10)         │              0 │ input_layer[0][0],     │
# │                           │                        │                │ multi_head_attention[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 20, 10)         │             20 │ add[0][0]              │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 20, 32)         │            352 │ layer_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization[0… │
# │                           │                        │                │ conv1d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_1     │ (None, 20, 10)         │             20 │ add_1[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_1    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_2     │ (None, 20, 10)         │             20 │ add_2[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_3 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_2… │
# │                           │                        │                │ conv1d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_3     │ (None, 20, 10)         │             20 │ add_3[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_2    │ (None, 20, 10)         │         22,026 │ layer_normalization_3… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_3… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_4     │ (None, 20, 10)         │             20 │ add_4[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_4 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_5 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_4… │
# │                           │                        │                │ conv1d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_5     │ (None, 20, 10)         │             20 │ add_5[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_3    │ (None, 20, 10)         │         22,026 │ layer_normalization_5… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_5… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_6     │ (None, 20, 10)         │             20 │ add_6[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_6 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_7 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_6… │
# │                           │                        │                │ conv1d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_7     │ (None, 20, 10)         │             20 │ add_7[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_4    │ (None, 20, 10)         │         22,026 │ layer_normalization_7… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_7… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_8     │ (None, 20, 10)         │             20 │ add_8[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_8 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_9 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_8… │
# │                           │                        │                │ conv1d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_9     │ (None, 20, 10)         │             20 │ add_9[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_5    │ (None, 20, 10)         │         22,026 │ layer_normalization_9… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_9… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_10    │ (None, 20, 10)         │             20 │ add_10[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_10 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_11 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_11    │ (None, 20, 10)         │             20 │ add_11[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_6    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_12    │ (None, 20, 10)         │             20 │ add_12[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_12 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_13 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_13 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_13    │ (None, 20, 10)         │             20 │ add_13[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_7    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 20, 10)         │             20 │ add_14[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_14 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_15 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_15 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 20, 10)         │             20 │ add_15[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 10)             │              0 │ layer_normalization_1… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │            704 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_16 (Dropout)      │ (None, 64)             │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 32)             │          2,080 │ dropout_16[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 32)             │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │             33 │ dropout_17[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 554,405 (2.11 MB)
#  Trainable params: 184,801 (721.88 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 369,604 (1.41 MB)

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) score
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2) score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.0296
# Mean Squared Error (MSE): 0.0013
# Root Mean Squared Error (RMSE): 0.0356
# R-squared (R2) score: 0.9791

# %%
# Plot the actual and predicted adjacent closing prices
# Assuming y_test and y_pred are numpy arrays
y_test = y_test.squeeze()
y_pred = y_pred.squeeze()

plt.figure(figsize=(10, 6))  # Increase figure size for better visibility

# Plot actual values as blue circles
plt.plot(y_test, label='Actual Adjacent Close', color='orange', marker='o', linestyle='-', markersize=5)

# Plot predicted values as red triangles
plt.plot(y_pred, label='Predicted Adjacent Close', color='green', marker='^', linestyle='--', markersize=5)

plt.xlabel('Time')
plt.ylabel('Adjacent Closing Price')
plt.title('Actual vs. Predicted Adjacent Closing Price')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
# Scatter plot of actual vs. predicted adjacent closing prices
plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

# Plot actual values as orange circles with larger markers
plt.scatter(y_test, y_test, color='orange', label='Actual Adjacent Closing Price', alpha=0.7, s=60)

# Plot predicted values as black crosses with smaller markers
plt.scatter(y_test, y_pred, color='green', label='Predicted Adjacent Closing Price', alpha=0.7, s=40, marker='x')

# Plot the diagonal line for perfect predictions
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--', label='Perfect Prediction')

plt.xlabel('Actual Adjacent Closing Price')
plt.ylabel('Predicted Adjacent Closing Price')
plt.title('Scatter Plot of Actual vs. Predicted Adjacent Closing Price')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
# Histogram of prediction errors
errors = y_test - y_pred

plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

plt.hist(errors, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Histogram of Prediction Errors')

# Add grid lines for better readability
plt.grid(True)

plt.show()
