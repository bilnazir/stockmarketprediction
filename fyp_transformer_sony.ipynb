# %% [markdown]
# <a href="https://colab.research.google.com/github/bilnazir/stockmarketprediction/blob/main/fyp_transformer_sony.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas-ta
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas-ta) (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=147a8df32adca4c4938d067b3a66149a1f7fed1fc22bd64abc3f94e1f824af91
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
import yfinance as yf

# %%
# Load historical stock data (date, closing price) into a pandas DataFrame
df = yf.download(tickers=['GOOG'], start='2012-01-01', end='2022-06-20')
data = df.dropna()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2633 entries, 2012-01-03 to 2022-06-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2633 non-null   float64
#  1   High       2633 non-null   float64
#  2   Low        2633 non-null   float64
#  3   Close      2633 non-null   float64
#  4   Adj Close  2633 non-null   float64
#  5   Volume     2633 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 144.0 KB

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   16.262545   16.641375   16.248346   16.573130   16.554291
# 2012-01-04   16.563665   16.693678   16.453827   16.644611   16.625692
# 2012-01-05   16.491436   16.537264   16.344486   16.413727   16.395069
# 2012-01-06   16.417213   16.438385   16.184088   16.189817   16.171415
# 2012-01-09   16.102144   16.114599   15.472754   15.503389   15.485767
# ...                ...         ...         ...         ...         ...
# 2022-06-13  107.445999  109.218498  106.588051  106.876503  106.755020
# 2022-06-14  106.889999  108.457497  106.351997  107.194000  107.072159
# 2022-06-15  108.899498  112.063004  108.118752  110.390503  110.265030
# 2022-06-16  108.149498  109.290497  105.792503  106.636002  106.514793
# 2022-06-17  106.535004  109.249496  105.628548  107.865501  107.742897
#
#                Volume
# Date
# 2012-01-03  147611217
# 2012-01-04  114989399
# 2012-01-05  131808205
# 2012-01-06  108119746
# 2012-01-09  233776981
# ...               ...
# 2022-06-13   36756000
# 2022-06-14   25480000
# 2022-06-15   33192000
# 2022-06-16   35314000
# 2022-06-17   43516000
#
# [2633 rows x 6 columns]

# %%
data.shape
# Out:
# (2633, 6)

# %%
# Adding indicators
import pandas_ta as ta
data['RSI'] = ta.rsi(data.Close, length=15)
data['EMAF'] = ta.ema(data.Close, length=20)
data['EMAM'] = ta.ema(data.Close, length=100)
data['EMAS'] = ta.ema(data.Close, length=150)

data['Target'] = data['Adj Close'] - data.Open
data['Target'] = data['Target'].shift(-1)

data['TargetClass'] = [1 if data.Target[i] > 0 else 0 for i in range(len(data))]

data['TargetNextClose'] = data['Adj Close'].shift(-1)

data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Volume', 'Close','Date'], axis=1, inplace=True)
# Out:
# <ipython-input-8-8a8148f44cbd>:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data['TargetClass'] = [1 if data.Target[i] > 0 else 0 for i in range(len(data))]

# %%
data_set = data.iloc[:, 0:11]
pd.set_option('display.max_columns', None)

data_set.head(20)
# Out:
#          Open       High        Low  Adj Close        RSI       EMAF  \
# 0   15.930538  16.173876  15.920825  15.992290  70.827616  15.289583
# 1   15.984835  16.046354  15.852332  15.935568  69.002748  15.352832
# 2   15.916591  16.086454  15.902892  15.977612  69.624298  15.414067
# 3   16.052582  16.098907  15.978110  15.980597  69.670565  15.469754
# 4   15.905134  15.996043  15.843863  15.971889  69.340468  15.519307
# 5   16.125059  16.442122  16.106628  16.419950  75.689867  15.606862
# 6   16.419704  16.758434  16.413479  16.635145  78.031058  15.706597
# 7   16.694426  16.793304  16.540503  16.607283  77.002297  15.794176
# 8   16.625435  16.803019  16.614723  16.739883  78.450911  15.886058
# 9   16.790068  16.868025  16.729794  16.846115  79.556274  15.979318
# 10  16.824438  16.908373  16.753702  16.806309  77.950961  16.059900
# 11  16.764912  16.886703  16.492432  16.656294  72.078335  16.118505
# 12  16.622196  16.951462  16.605259  16.847111  74.678191  16.189721
# 13  16.793802  16.948473  16.712358  16.837656  74.310909  16.253254
# 14  16.826929  16.947725  16.789070  16.883183  74.946682  16.315077
# 15  16.512856  16.737265  16.419456  16.649078  65.953679  16.348691
# 16  16.562918  16.877239  16.556442  16.848852  69.319601  16.398152
# 17  16.871014  17.160429  16.840628  17.116543  73.133003  16.468425
# 18  17.042122  17.120579  16.941002  16.959063  67.819720  16.516990
# 19  17.036144  17.150217  16.937513  17.043898  69.114855  16.569019
#
#          EMAM       EMAS    Target  TargetClass  TargetNextClose
# 0   14.981082  15.106479 -0.049267            0        15.935568
# 1   15.000342  15.117700  0.061022            1        15.977612
# 2   15.020054  15.129331 -0.071984            0        15.980597
# 3   15.039434  15.140847  0.066755            1        15.971889
# 4   15.058259  15.152095  0.294891            1        16.419950
# 5   15.085593  15.169135  0.215441            1        16.635145
# 6   15.116652  15.188803 -0.087143            0        16.607283
# 7   15.146544  15.207841  0.114449            1        16.739883
# 8   15.178472  15.228385  0.056047            1        16.846115
# 9   15.211874  15.250066 -0.018129            0        16.806309
# 10  15.243826  15.270932 -0.108618            0        16.656294
# 11  15.272171  15.289532  0.224915            1        16.847111
# 12  15.303738  15.310416  0.043854            1        16.837656
# 13  15.334492  15.330898  0.056253            1        16.883183
# 14  15.365539  15.351713  0.136223            1        16.649078
# 15  15.391331  15.369147  0.285934            1        16.848852
# 16  15.420573  15.389000  0.245529            1        17.116543
# 17  15.454542  15.412139 -0.083059            0        16.959063
# 18  15.484716  15.432884  0.007753            1        17.043898
# 19  15.515975  15.454479 -0.106703            0        16.943140

# %%
import matplotlib.pyplot as plt
data_set_AC=data_set['Adj Close']
plt.ylabel('Up-Down Movemetn')
plt.xlabel('Date')
plt.plot(data_set_AC)

# %%
# Normalize the data
sc = MinMaxScaler(feature_range=(0, 1))
data_set_scaled = sc.fit_transform(data)

# %%
# Prepare the data for training
X, y = [], []
backcandles = 20
for i in range(backcandles, data_set_scaled.shape[0]):
    X.append(data_set_scaled[i - backcandles:i, :-1])
    y.append(data_set_scaled[i, -1])

X, y = np.array(X), np.array(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Build the Transformer model
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-head self-attention mechanism
    attn_output = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    attn_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)

    # Feed-forward neural network
    ffn_output = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(attn_output)
    ffn_output = tf.keras.layers.Dropout(dropout)(ffn_output)
    ffn_output = tf.keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(ffn_output)
    return tf.keras.layers.LayerNormalization(epsilon=1e-6)(attn_output + ffn_output)

# %%
# Build the Transformer model
def build_transformer_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
):
    inputs = Input(shape=input_shape)

    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = tf.keras.layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = Dense(dim, activation="relu")(x)
        x = Dropout(dropout)(x)
    outputs = Dense(1)(x)

    return Model(inputs, outputs)

# %%
input_shape = X_train.shape[1:]
head_size = 128
num_heads = 4
ff_dim = 32
num_transformer_blocks = 8
mlp_units = [64, 32]

# %%
# Create and compile the Transformer model
model = build_transformer_model(
    input_shape,
    head_size=head_size,
    num_heads=num_heads,
    ff_dim=ff_dim,
    num_transformer_blocks=num_transformer_blocks,
    mlp_units=mlp_units,
    dropout=0.25,
)

model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

# %%
# Training the model
history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=128,
    validation_data=(X_test, y_test),
    verbose=1,
)
# Out:
# Epoch 1/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 39s 455ms/step - loss: 0.0947 - mean_absolute_error: 0.2303 - val_loss: 0.0057 - val_mean_absolute_error: 0.0633
# Epoch 2/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - loss: 0.0225 - mean_absolute_error: 0.1111 - val_loss: 0.0056 - val_mean_absolute_error: 0.0612
# Epoch 3/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - loss: 0.0156 - mean_absolute_error: 0.0845 - val_loss: 0.0032 - val_mean_absolute_error: 0.0429
# Epoch 4/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - loss: 0.0118 - mean_absolute_error: 0.0775 - val_loss: 0.0045 - val_mean_absolute_error: 0.0563
# Epoch 5/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - loss: 0.0128 - mean_absolute_error: 0.0758 - val_loss: 0.0041 - val_mean_absolute_error: 0.0485
# Epoch 6/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 411ms/step - loss: 0.0115 - mean_absolute_error: 0.0732 - val_loss: 0.0088 - val_mean_absolute_error: 0.0817
# Epoch 7/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - loss: 0.0072 - mean_absolute_error: 0.0601 - val_loss: 0.0030 - val_mean_absolute_error: 0.0434
# Epoch 8/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - loss: 0.0077 - mean_absolute_error: 0.0600 - val_loss: 0.0025 - val_mean_absolute_error: 0.0415
# Epoch 9/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - loss: 0.0074 - mean_absolute_error: 0.0614 - val_loss: 0.0017 - val_mean_absolute_error: 0.0291
# Epoch 10/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 403ms/step - loss: 0.0086 - mean_absolute_error: 0.0652 - val_loss: 0.0038 - val_mean_absolute_error: 0.0488
# Epoch 11/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 406ms/step - loss: 0.0088 - mean_absolute_error: 0.0640 - val_loss: 0.0081 - val_mean_absolute_error: 0.0796
# Epoch 12/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - loss: 0.0098 - mean_absolute_error: 0.0681 - val_loss: 0.0086 - val_mean_absolute_error: 0.0570
# Epoch 13/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 406ms/step - loss: 0.0086 - mean_absolute_error: 0.0595 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 14/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - loss: 0.0056 - mean_absolute_error: 0.0514 - val_loss: 0.0018 - val_mean_absolute_error: 0.0335
# Epoch 15/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 379ms/step - loss: 0.0065 - mean_absolute_error: 0.0526 - val_loss: 0.0033 - val_mean_absolute_error: 0.0439
# Epoch 16/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - loss: 0.0069 - mean_absolute_error: 0.0532 - val_loss: 0.0021 - val_mean_absolute_error: 0.0308
# Epoch 17/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 392ms/step - loss: 0.0052 - mean_absolute_error: 0.0477 - val_loss: 0.0012 - val_mean_absolute_error: 0.0263
# Epoch 18/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 406ms/step - loss: 0.0056 - mean_absolute_error: 0.0482 - val_loss: 0.0017 - val_mean_absolute_error: 0.0272
# Epoch 19/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 400ms/step - loss: 0.0062 - mean_absolute_error: 0.0507 - val_loss: 7.6451e-04 - val_mean_absolute_error: 0.0201
# Epoch 20/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 339ms/step - loss: 0.0052 - mean_absolute_error: 0.0488 - val_loss: 0.0020 - val_mean_absolute_error: 0.0303
# Epoch 21/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 399ms/step - loss: 0.0054 - mean_absolute_error: 0.0496 - val_loss: 0.0028 - val_mean_absolute_error: 0.0373
# Epoch 22/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - loss: 0.0064 - mean_absolute_error: 0.0533 - val_loss: 0.0023 - val_mean_absolute_error: 0.0394
# Epoch 23/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - loss: 0.0051 - mean_absolute_error: 0.0449 - val_loss: 0.0031 - val_mean_absolute_error: 0.0461
# Epoch 24/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - loss: 0.0052 - mean_absolute_error: 0.0499 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 25/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 367ms/step - loss: 0.0059 - mean_absolute_error: 0.0507 - val_loss: 9.4466e-04 - val_mean_absolute_error: 0.0218
# Epoch 26/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 414ms/step - loss: 0.0041 - mean_absolute_error: 0.0412 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 27/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - loss: 0.0050 - mean_absolute_error: 0.0456 - val_loss: 8.5945e-04 - val_mean_absolute_error: 0.0220
# Epoch 28/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 366ms/step - loss: 0.0043 - mean_absolute_error: 0.0436 - val_loss: 0.0013 - val_mean_absolute_error: 0.0298
# Epoch 29/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 412ms/step - loss: 0.0045 - mean_absolute_error: 0.0454 - val_loss: 8.4450e-04 - val_mean_absolute_error: 0.0216
# Epoch 30/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 373ms/step - loss: 0.0043 - mean_absolute_error: 0.0431 - val_loss: 9.2012e-04 - val_mean_absolute_error: 0.0237
# Epoch 31/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - loss: 0.0044 - mean_absolute_error: 0.0427 - val_loss: 0.0013 - val_mean_absolute_error: 0.0292
# Epoch 32/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 411ms/step - loss: 0.0057 - mean_absolute_error: 0.0485 - val_loss: 9.1462e-04 - val_mean_absolute_error: 0.0227
# Epoch 33/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 423ms/step - loss: 0.0049 - mean_absolute_error: 0.0453 - val_loss: 0.0014 - val_mean_absolute_error: 0.0254
# Epoch 34/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - loss: 0.0046 - mean_absolute_error: 0.0435 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 35/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 385ms/step - loss: 0.0049 - mean_absolute_error: 0.0455 - val_loss: 0.0023 - val_mean_absolute_error: 0.0405
# Epoch 36/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - loss: 0.0051 - mean_absolute_error: 0.0483 - val_loss: 0.0014 - val_mean_absolute_error: 0.0324
# Epoch 37/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 364ms/step - loss: 0.0037 - mean_absolute_error: 0.0412 - val_loss: 8.5031e-04 - val_mean_absolute_error: 0.0210
# Epoch 38/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 414ms/step - loss: 0.0038 - mean_absolute_error: 0.0407 - val_loss: 7.0831e-04 - val_mean_absolute_error: 0.0199
# Epoch 39/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 374ms/step - loss: 0.0044 - mean_absolute_error: 0.0422 - val_loss: 7.0968e-04 - val_mean_absolute_error: 0.0205
# Epoch 40/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 366ms/step - loss: 0.0036 - mean_absolute_error: 0.0392 - val_loss: 0.0017 - val_mean_absolute_error: 0.0305
# Epoch 41/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - loss: 0.0045 - mean_absolute_error: 0.0446 - val_loss: 7.2045e-04 - val_mean_absolute_error: 0.0198
# Epoch 42/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 409ms/step - loss: 0.0044 - mean_absolute_error: 0.0436 - val_loss: 6.8528e-04 - val_mean_absolute_error: 0.0198
# Epoch 43/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 338ms/step - loss: 0.0038 - mean_absolute_error: 0.0404 - val_loss: 7.6971e-04 - val_mean_absolute_error: 0.0192
# Epoch 44/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 410ms/step - loss: 0.0036 - mean_absolute_error: 0.0407 - val_loss: 8.5854e-04 - val_mean_absolute_error: 0.0231
# Epoch 45/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - loss: 0.0033 - mean_absolute_error: 0.0401 - val_loss: 0.0014 - val_mean_absolute_error: 0.0272
# Epoch 46/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 341ms/step - loss: 0.0039 - mean_absolute_error: 0.0433 - val_loss: 9.6760e-04 - val_mean_absolute_error: 0.0223
# Epoch 47/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 411ms/step - loss: 0.0043 - mean_absolute_error: 0.0421 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 48/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 435ms/step - loss: 0.0043 - mean_absolute_error: 0.0449 - val_loss: 6.0931e-04 - val_mean_absolute_error: 0.0187
# Epoch 49/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 398ms/step - loss: 0.0039 - mean_absolute_error: 0.0402 - val_loss: 8.5744e-04 - val_mean_absolute_error: 0.0211
# Epoch 50/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 404ms/step - loss: 0.0036 - mean_absolute_error: 0.0407 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 51/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 409ms/step - loss: 0.0039 - mean_absolute_error: 0.0421 - val_loss: 8.7504e-04 - val_mean_absolute_error: 0.0234
# Epoch 52/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - val_loss: 7.7301e-04 - val_mean_absolute_error: 0.0212
# Epoch 53/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 398ms/step - loss: 0.0033 - mean_absolute_error: 0.0393 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 54/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - loss: 0.0043 - mean_absolute_error: 0.0454 - val_loss: 7.7565e-04 - val_mean_absolute_error: 0.0204
# Epoch 55/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 384ms/step - loss: 0.0034 - mean_absolute_error: 0.0391 - val_loss: 7.1843e-04 - val_mean_absolute_error: 0.0199
# Epoch 56/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 400ms/step - loss: 0.0039 - mean_absolute_error: 0.0415 - val_loss: 6.6036e-04 - val_mean_absolute_error: 0.0195
# Epoch 57/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 340ms/step - loss: 0.0037 - mean_absolute_error: 0.0387 - val_loss: 9.7474e-04 - val_mean_absolute_error: 0.0226
# Epoch 58/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 383ms/step - loss: 0.0030 - mean_absolute_error: 0.0372 - val_loss: 8.3685e-04 - val_mean_absolute_error: 0.0248
# Epoch 59/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 409ms/step - loss: 0.0038 - mean_absolute_error: 0.0412 - val_loss: 9.3086e-04 - val_mean_absolute_error: 0.0246
# Epoch 60/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 409ms/step - loss: 0.0040 - mean_absolute_error: 0.0433 - val_loss: 9.2028e-04 - val_mean_absolute_error: 0.0204
# Epoch 61/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - loss: 0.0034 - mean_absolute_error: 0.0385 - val_loss: 8.9070e-04 - val_mean_absolute_error: 0.0254
# Epoch 62/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - loss: 0.0037 - mean_absolute_error: 0.0398 - val_loss: 6.6134e-04 - val_mean_absolute_error: 0.0199
# Epoch 63/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 404ms/step - loss: 0.0035 - mean_absolute_error: 0.0398 - val_loss: 6.0648e-04 - val_mean_absolute_error: 0.0181
# Epoch 64/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 406ms/step - loss: 0.0036 - mean_absolute_error: 0.0393 - val_loss: 6.4531e-04 - val_mean_absolute_error: 0.0184
# Epoch 65/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - loss: 0.0034 - mean_absolute_error: 0.0391 - val_loss: 8.5549e-04 - val_mean_absolute_error: 0.0241
# Epoch 66/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - loss: 0.0032 - mean_absolute_error: 0.0379 - val_loss: 6.5222e-04 - val_mean_absolute_error: 0.0195
# Epoch 67/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 382ms/step - loss: 0.0033 - mean_absolute_error: 0.0386 - val_loss: 7.7650e-04 - val_mean_absolute_error: 0.0193
# Epoch 68/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - loss: 0.0035 - mean_absolute_error: 0.0392 - val_loss: 6.5565e-04 - val_mean_absolute_error: 0.0202
# Epoch 69/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 395ms/step - loss: 0.0034 - mean_absolute_error: 0.0393 - val_loss: 0.0014 - val_mean_absolute_error: 0.0311
# Epoch 70/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - loss: 0.0033 - mean_absolute_error: 0.0396 - val_loss: 0.0018 - val_mean_absolute_error: 0.0348
# Epoch 71/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 406ms/step - loss: 0.0038 - mean_absolute_error: 0.0417 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 72/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 410ms/step - loss: 0.0038 - mean_absolute_error: 0.0415 - val_loss: 8.3848e-04 - val_mean_absolute_error: 0.0212
# Epoch 73/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 400ms/step - loss: 0.0033 - mean_absolute_error: 0.0386 - val_loss: 0.0011 - val_mean_absolute_error: 0.0220
# Epoch 74/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - loss: 0.0034 - mean_absolute_error: 0.0383 - val_loss: 7.0922e-04 - val_mean_absolute_error: 0.0202
# Epoch 75/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - loss: 0.0033 - mean_absolute_error: 0.0376 - val_loss: 0.0014 - val_mean_absolute_error: 0.0247
# Epoch 76/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - loss: 0.0035 - mean_absolute_error: 0.0411 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 77/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 376ms/step - loss: 0.0038 - mean_absolute_error: 0.0425 - val_loss: 7.1460e-04 - val_mean_absolute_error: 0.0197
# Epoch 78/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - loss: 0.0035 - mean_absolute_error: 0.0400 - val_loss: 7.1946e-04 - val_mean_absolute_error: 0.0190
# Epoch 79/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 337ms/step - loss: 0.0034 - mean_absolute_error: 0.0392 - val_loss: 0.0010 - val_mean_absolute_error: 0.0272
# Epoch 80/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 410ms/step - loss: 0.0033 - mean_absolute_error: 0.0379 - val_loss: 8.7098e-04 - val_mean_absolute_error: 0.0205
# Epoch 81/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - loss: 0.0032 - mean_absolute_error: 0.0371 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 82/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 409ms/step - loss: 0.0030 - mean_absolute_error: 0.0390 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 83/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - loss: 0.0035 - mean_absolute_error: 0.0395 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 84/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - loss: 0.0032 - mean_absolute_error: 0.0388 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 85/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - loss: 0.0029 - mean_absolute_error: 0.0370 - val_loss: 7.9386e-04 - val_mean_absolute_error: 0.0205
# Epoch 86/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - loss: 0.0029 - mean_absolute_error: 0.0375 - val_loss: 7.0000e-04 - val_mean_absolute_error: 0.0224
# Epoch 87/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 369ms/step - loss: 0.0030 - mean_absolute_error: 0.0368 - val_loss: 8.6086e-04 - val_mean_absolute_error: 0.0241
# Epoch 88/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - loss: 0.0030 - mean_absolute_error: 0.0377 - val_loss: 0.0012 - val_mean_absolute_error: 0.0208
# Epoch 89/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0030 - mean_absolute_error: 0.0363 - val_loss: 8.8111e-04 - val_mean_absolute_error: 0.0242
# Epoch 90/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 338ms/step - loss: 0.0036 - mean_absolute_error: 0.0385 - val_loss: 5.9191e-04 - val_mean_absolute_error: 0.0199
# Epoch 91/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 403ms/step - loss: 0.0030 - mean_absolute_error: 0.0364 - val_loss: 0.0010 - val_mean_absolute_error: 0.0270
# Epoch 92/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 399ms/step - loss: 0.0030 - mean_absolute_error: 0.0368 - val_loss: 7.4443e-04 - val_mean_absolute_error: 0.0190
# Epoch 93/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 372ms/step - loss: 0.0036 - mean_absolute_error: 0.0390 - val_loss: 0.0010 - val_mean_absolute_error: 0.0261
# Epoch 94/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 411ms/step - loss: 0.0031 - mean_absolute_error: 0.0376 - val_loss: 8.4172e-04 - val_mean_absolute_error: 0.0241
# Epoch 95/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 409ms/step - loss: 0.0030 - mean_absolute_error: 0.0360 - val_loss: 6.2412e-04 - val_mean_absolute_error: 0.0202
# Epoch 96/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - loss: 0.0032 - mean_absolute_error: 0.0385 - val_loss: 7.4577e-04 - val_mean_absolute_error: 0.0231
# Epoch 97/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 369ms/step - loss: 0.0027 - mean_absolute_error: 0.0353 - val_loss: 4.9445e-04 - val_mean_absolute_error: 0.0159
# Epoch 98/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 412ms/step - loss: 0.0031 - mean_absolute_error: 0.0377 - val_loss: 8.4682e-04 - val_mean_absolute_error: 0.0249
# Epoch 99/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 415ms/step - loss: 0.0027 - mean_absolute_error: 0.0355 - val_loss: 0.0012 - val_mean_absolute_error: 0.0294
# Epoch 100/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 380ms/step - loss: 0.0033 - mean_absolute_error: 0.0398 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 101/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - loss: 0.0033 - mean_absolute_error: 0.0382 - val_loss: 6.0352e-04 - val_mean_absolute_error: 0.0183
# Epoch 102/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 371ms/step - loss: 0.0032 - mean_absolute_error: 0.0378 - val_loss: 0.0012 - val_mean_absolute_error: 0.0251
# Epoch 103/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 373ms/step - loss: 0.0036 - mean_absolute_error: 0.0401 - val_loss: 4.9849e-04 - val_mean_absolute_error: 0.0161
# Epoch 104/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - loss: 0.0026 - mean_absolute_error: 0.0355 - val_loss: 5.0678e-04 - val_mean_absolute_error: 0.0175
# Epoch 105/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 338ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0017 - val_mean_absolute_error: 0.0302
# Epoch 106/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 389ms/step - loss: 0.0032 - mean_absolute_error: 0.0381 - val_loss: 7.0697e-04 - val_mean_absolute_error: 0.0184
# Epoch 107/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - val_loss: 6.3492e-04 - val_mean_absolute_error: 0.0181
# Epoch 108/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - loss: 0.0028 - mean_absolute_error: 0.0354 - val_loss: 0.0020 - val_mean_absolute_error: 0.0387
# Epoch 109/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 361ms/step - loss: 0.0029 - mean_absolute_error: 0.0374 - val_loss: 0.0013 - val_mean_absolute_error: 0.0255
# Epoch 110/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 403ms/step - loss: 0.0036 - mean_absolute_error: 0.0410 - val_loss: 9.9863e-04 - val_mean_absolute_error: 0.0223
# Epoch 111/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - loss: 0.0032 - mean_absolute_error: 0.0379 - val_loss: 6.1675e-04 - val_mean_absolute_error: 0.0201
# Epoch 112/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - loss: 0.0026 - mean_absolute_error: 0.0357 - val_loss: 0.0017 - val_mean_absolute_error: 0.0353
# Epoch 113/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 406ms/step - loss: 0.0029 - mean_absolute_error: 0.0385 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 114/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 338ms/step - loss: 0.0031 - mean_absolute_error: 0.0373 - val_loss: 6.9330e-04 - val_mean_absolute_error: 0.0181
# Epoch 115/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - loss: 0.0028 - mean_absolute_error: 0.0374 - val_loss: 6.6788e-04 - val_mean_absolute_error: 0.0207
# Epoch 116/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 407ms/step - loss: 0.0030 - mean_absolute_error: 0.0368 - val_loss: 9.2128e-04 - val_mean_absolute_error: 0.0258
# Epoch 117/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 9.1565e-04 - val_mean_absolute_error: 0.0255
# Epoch 118/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 383ms/step - loss: 0.0030 - mean_absolute_error: 0.0378 - val_loss: 5.0068e-04 - val_mean_absolute_error: 0.0165
# Epoch 119/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - loss: 0.0022 - mean_absolute_error: 0.0330 - val_loss: 0.0010 - val_mean_absolute_error: 0.0226
# Epoch 120/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 392ms/step - loss: 0.0032 - mean_absolute_error: 0.0380 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 121/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 406ms/step - loss: 0.0030 - mean_absolute_error: 0.0378 - val_loss: 0.0016 - val_mean_absolute_error: 0.0359
# Epoch 122/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 405ms/step - loss: 0.0037 - mean_absolute_error: 0.0425 - val_loss: 8.6026e-04 - val_mean_absolute_error: 0.0208
# Epoch 123/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 414ms/step - loss: 0.0030 - mean_absolute_error: 0.0387 - val_loss: 0.0011 - val_mean_absolute_error: 0.0271
# Epoch 124/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 337ms/step - loss: 0.0034 - mean_absolute_error: 0.0396 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 125/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 412ms/step - loss: 0.0030 - mean_absolute_error: 0.0378 - val_loss: 5.8882e-04 - val_mean_absolute_error: 0.0187
# Epoch 126/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 406ms/step - loss: 0.0028 - mean_absolute_error: 0.0364 - val_loss: 8.0775e-04 - val_mean_absolute_error: 0.0196
# Epoch 127/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - loss: 0.0030 - mean_absolute_error: 0.0375 - val_loss: 6.3066e-04 - val_mean_absolute_error: 0.0185
# Epoch 128/128
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 409ms/step - loss: 0.0028 - mean_absolute_error: 0.0363 - val_loss: 5.6823e-04 - val_mean_absolute_error: 0.0190

# %%
# Convert training history to datafram for viewing and graphing.
hist = pd.DataFrame(history.history)
hist.head()
# Out:
#        loss  mean_absolute_error  val_loss  val_mean_absolute_error
# 0  0.057007             0.172135  0.005712                 0.063289
# 1  0.019882             0.102993  0.005643                 0.061160
# 2  0.014432             0.083334  0.003233                 0.042898
# 3  0.011315             0.075098  0.004463                 0.056317
# 4  0.012278             0.074448  0.004083                 0.048507

# %%
# Training errors with respect to ecochs.
# loss: values of the cost function for training data.
# val_loss: values of the cost function for cross-validation data.
hist.plot()
# Out:
# <Axes: >

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 20, 10)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 20, 10)         │         22,026 │ input_layer[0][0],     │
# │ (MultiHeadAttention)      │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 20, 10)         │              0 │ input_layer[0][0],     │
# │                           │                        │                │ multi_head_attention[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 20, 10)         │             20 │ add[0][0]              │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 20, 32)         │            352 │ layer_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization[0… │
# │                           │                        │                │ conv1d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_1     │ (None, 20, 10)         │             20 │ add_1[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_1    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_2     │ (None, 20, 10)         │             20 │ add_2[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_3 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_2… │
# │                           │                        │                │ conv1d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_3     │ (None, 20, 10)         │             20 │ add_3[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_2    │ (None, 20, 10)         │         22,026 │ layer_normalization_3… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_3… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_4     │ (None, 20, 10)         │             20 │ add_4[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_4 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_5 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_4… │
# │                           │                        │                │ conv1d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_5     │ (None, 20, 10)         │             20 │ add_5[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_3    │ (None, 20, 10)         │         22,026 │ layer_normalization_5… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_5… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_6     │ (None, 20, 10)         │             20 │ add_6[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_6 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_7 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_6… │
# │                           │                        │                │ conv1d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_7     │ (None, 20, 10)         │             20 │ add_7[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_4    │ (None, 20, 10)         │         22,026 │ layer_normalization_7… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_7… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_8     │ (None, 20, 10)         │             20 │ add_8[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_8 (Conv1D)         │ (None, 20, 32)         │            352 │ layer_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 20, 32)         │              0 │ conv1d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_9 (Conv1D)         │ (None, 20, 10)         │            330 │ dropout_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 20, 10)         │              0 │ layer_normalization_8… │
# │                           │                        │                │ conv1d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_9     │ (None, 20, 10)         │             20 │ add_9[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_5    │ (None, 20, 10)         │         22,026 │ layer_normalization_9… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_9… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_10    │ (None, 20, 10)         │             20 │ add_10[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_10 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_11 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_11    │ (None, 20, 10)         │             20 │ add_11[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_6    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_12    │ (None, 20, 10)         │             20 │ add_12[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_12 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_13 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_13 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_13    │ (None, 20, 10)         │             20 │ add_13[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_7    │ (None, 20, 10)         │         22,026 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 20, 10)         │             20 │ add_14[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_14 (Conv1D)        │ (None, 20, 32)         │            352 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_15 (Dropout)      │ (None, 20, 32)         │              0 │ conv1d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_15 (Conv1D)        │ (None, 20, 10)         │            330 │ dropout_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 20, 10)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ conv1d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 20, 10)         │             20 │ add_15[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 10)             │              0 │ layer_normalization_1… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │            704 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_16 (Dropout)      │ (None, 64)             │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 32)             │          2,080 │ dropout_16[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 32)             │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │             33 │ dropout_17[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 554,405 (2.11 MB)
#  Trainable params: 184,801 (721.88 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 369,604 (1.41 MB)

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) score
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2) score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.0190
# Mean Squared Error (MSE): 0.0006
# Root Mean Squared Error (RMSE): 0.0238
# R-squared (R2) score: 0.9907

# %%
# Plot the actual and predicted adjacent closing prices
# Assuming y_test and y_pred are numpy arrays
y_test = y_test.squeeze()
y_pred = y_pred.squeeze()

plt.figure(figsize=(10, 6))  # Increase figure size for better visibility

# Plot actual values as blue circles
plt.plot(y_test, label='Actual Adjacent Close', color='orange', marker='o', linestyle='-', markersize=5)

# Plot predicted values as red triangles
plt.plot(y_pred, label='Predicted Adjacent Close', color='green', marker='^', linestyle='--', markersize=5)

plt.xlabel('Time')
plt.ylabel('Adjacent Closing Price')
plt.title('Actual vs. Predicted Adjacent Closing Price')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
# Scatter plot of actual vs. predicted adjacent closing prices
plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

# Plot actual values as orange circles with larger markers
plt.scatter(y_test, y_test, color='orange', label='Actual Adjacent Closing Price', alpha=0.7, s=60)

# Plot predicted values as black crosses with smaller markers
plt.scatter(y_test, y_pred, color='green', label='Predicted Adjacent Closing Price', alpha=0.7, s=40, marker='x')

# Plot the diagonal line for perfect predictions
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--', label='Perfect Prediction')

plt.xlabel('Actual Adjacent Closing Price')
plt.ylabel('Predicted Adjacent Closing Price')
plt.title('Scatter Plot of Actual vs. Predicted Adjacent Closing Price')
plt.legend()
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
# Histogram of prediction errors
errors = y_test - y_pred

plt.figure(figsize=(8, 6))  # Increase figure size for better visibility

plt.hist(errors, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Histogram of Prediction Errors')

# Add grid lines for better readability
plt.grid(True)

plt.show()
